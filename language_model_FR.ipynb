# %% [markdown]
# # NLP Lab : Modèles de langue
#
# Dans ce tp, nous allons constuire les briques principales du modèle GPT2 et entrainer un petit modèle sur des poèmes de Victor Hugo.
#
# Les questions sont posées dans ce notebook, puis pour executer l'entrainement, il faudra modifier le ficher `gpt_single_head.py` aussi disponible dans le reposository git.
#
#
# ## Données
#
# Les données d'entrainement sont un recueil de poèmes de Victor Hugo issu du site [gutenberg.org](https://www.gutenberg.org/). Elles sont disponibles dans le répertoire `data`.
#
# Afin de réduire la complexité du modèle, nous allons modéliser le texte au niveau caractère. Les modèles de language modélisent généralement des séquences de sous-mots en utilisant des [tokenizers](https://huggingface.co/docs/transformers/tokenizer_summary) (BPE, SentencePiece, WordPiece)
#
# Questions :
# >* En utilisant [collections.Counter](https://docs.python.org/3/library/collections.html#collections.Counter), afficher le nombre de caractères différents dans le texte et la fréquence de chaque caractère.

# %%
# Out:
# 0.009989 M parameters
# step 0: train loss 4.6896, val loss 4.6661
# step 500: train loss 0.5564, val loss 0.5934
# step 1000: train loss 0.4698, val loss 0.4759
# step 1500: train loss 0.4441, val loss 0.4480
# step 2000: train loss 0.4219, val loss 0.4275
# step 2500: train loss 0.4204, val loss 0.4200
# step 3000: train loss 0.4118, val loss 0.4103
# step 3500: train loss 0.4056, val loss 0.4098
# step 4000: train loss 0.3988, val loss 0.3949
# step 4500: train loss 0.4033, val loss 0.3929
# step 4999: train loss 0.3988, val loss 0.3885
#
# LLLLLLLLLLLLLL'...
# 0.009989 M parameters
# step 0: train loss 4.6896, val loss 4.6661
# step 500: train loss 0.5564, val loss 0.5934
# step 1000: train loss 0.4698, val loss 0.4759
# step 1500: train loss 0.4441, val loss 0.4480
# step 2000: train loss 0.4219, val loss 0.4275
# step 2500: train loss 0.4204, val loss 0.4200
# step 3000: train loss 0.4118, val loss 0.4103
# step 3500: train loss 0.4056, val loss 0.4098
# step 4000: train loss 0.3988, val loss 0.3949
# step 4500: train loss 0.4033, val loss 0.3929
# step 4999: train loss 0.3988, val loss 0.3885
#
# LLLLLLLLLLLLLL'...
# <module 'gpt_single_head' from '/home/onyxia/work/nlp-lab_language-models/gpt_single_head.py'>

# %%
import collections

with open('data/hugo_contemplations.txt', 'r', encoding='utf-8') as f:
    text = f.read()

print(f'Number of characters in the file: {len(text)}')
##  YOUR CODE HERE

counter = collections.Counter(text)

###

print (f'Number of character in counter: {sum(counter.values())}')
print (f'{len(counter)} different characters')
print (counter)
# Out:
# Number of characters in the file: 285222
# Number of character in counter: 285222
# 101 different characters
# Counter({' ': 49127, 'e': 30253, 's': 17987, 'u': 14254, 'r': 14223, 't': 14071, 'a': 14048, 'n': 13725, 'i': 12828, 'o': 12653, 'l': 11638, '\n': 8102, 'm': 6495, 'd': 6375, ',': 6077, 'c': 5074, 'p': 4206, "'": 3820, 'v': 3492, 'é': 2943, 'b': 2783, 'f': 2772, 'h': 2221, 'q': 1956, 'g': 1790, '.': 1420, 'x': 1154, 'L': 1147, '!': 1121, 'E': 1074, ';': 1043, '-': 1020, 'j': 890, 'D': 764, 'è': 725, 'à': 706, 'y': 660, 'I': 627, 'ê': 605, 'C': 593, 'S': 545, 'A': 530, 'Q': 503, 'z': 482, 'J': 471, 'O': 450, 'T': 441, 'P': 435, '?': 388, 'V': 383, 'â': 381, 'N': 362, 'M': 344, 'ù': 298, ':': 294, 'R': 240, 'î': 214, 'U': 208, 'ô': 159, 'X': 150, '1': 146, 'H': 116, 'F': 114, '5': 111, '8': 93, 'B': 78, '«': 74, 'É': 70, '»': 69, 'G': 67, '4': 64, 'û': 62, '3': 47, 'ç': 34, 'À': 33, 'ë': 32, 'ï': 31, '2': 30, '·': 26, 'Ê': 24, '6': 23, '7': 23, 'Ô': 19, '9': 19, 'È': 11, 'k': 10, '0': 10, '_': 8, 'Z': 7, 'Æ': 4, '[': 4, ']': 4, 'w': 3, 'K': 3, 'Y': 3, 'Ë': 2, '(': 2, ')': 2, 'Â': 2, 'Î': 1, 'W': 1})

# %%
# here are all the unique characters that occur in this text
chars = sorted(list(set(text)))
vocab_size = len(chars)
# create a mapping from characters to integers
stoi = { ch:i for i,ch in enumerate(chars) }
itos = { i:ch for i,ch in enumerate(chars) }
encode = lambda s: [stoi[c] for c in s] # encoder: take a string, output a list of integers
decode = lambda l: ''.join([itos[i] for i in l]) # decoder: take a list of integers, output a string

# %% [markdown]
# ### Encodage / décodage
# Afin de transformer le texte en vecteur pour le réseau de neurones, il faut encoder chaque caractère avec un entier. Les fonctions suivantes opérent l'encodage et le décodage des caractères :

# %%
# create a mapping from characters to integers
stoi = { ch:i for i,ch in enumerate(counter) }
itos = { i:ch for i,ch in enumerate(counter) }
encode = lambda s: [stoi[c] for c in s] # encoder: transform a string into a list of integers
decode = lambda l: ''.join([itos[i] for i in l]) # decoder: transform a list of integers into a string


# test that your encoder/decoder is coherent
testString = "\nDemain, dès l'aube"
assert decode(encode (testString)) ==  testString

# %% [markdown]
# ### Découpage Train/Validation
#
# L'objectif étant de prédire des poèmes, il ne faut pas mélanger les lignes aléatoirement. Il faut garder l'ordre des lignes dans le texte et uniquement prendre les premiers 90% pour entrainer et les 10% restants pour contrôler l'apprentissage.
#
# Questions :
# > * Découper en `train_data` (90%) et `val_data` (10%) en utilisant du slicing sur data.

# %%
#!pip install torch

# %%
import torch
# Train and validation splits
data = torch.tensor(encode(text), dtype=torch.long)
## YOUR CODE HERE
# first 90% will be train, rest val
# Calcul de l'indice de séparation
split_idx = int(0.9 * len(data))

# Division desz données en ensembles d'entraînement et de validation
train_data = data[:split_idx]
val_data = data[split_idx:]
###

# %% [markdown]
# ### Contexte
#
# Le modèle de langue possède comme paramètre la taille maximale du contexte à considérer pour faire la prédiction du prochain caractère. Ce contexte est appelé `block_size`. Les données d'apprentissage sont donc des séquences de caractères consécutifs, issues de l'ensemble d'entraînenement tirées aléatoirement et de longueur `block_size`.
#
# Si le caractère de début de la séquence est `i`, la séquence de contexte est donc :
# ``` x = data[i:i+block_size]```
# et la valeur à prédire à chaque position dans le contexte est le caractère suivant :
# ```y = [data[i+1:i+block_size+1]```.

# %%
block_size = 8

i  = torch.randint(len(data) - block_size, (1,))
print (i)
x = train_data[i:i+block_size]
y = train_data[i+1:i+1+block_size]

for t in range(block_size):
    context = x[:t+1]
    target = y[t]
    print (f'context is >{decode(context.tolist())}< target is >{decode([target.tolist()])}<')
# Out:
# tensor([175930])
# context is >é< target is >j<
# context is >éj< target is >à<
# context is >éjà< target is > <
# context is >éjà < target is >p<
# context is >éjà p< target is >r<
# context is >éjà pr< target is >i<
# context is >éjà pri< target is >s<
# context is >éjà pris< target is > <

# %% [markdown]
# ### Définition des batchs
#
# Les batchs d'entrainement sont constitués de plusieurs séquences de caractères tirées aléatoirement dans `train_data`. Pour choisir aléatoirement une séquence à mettre dans le batch, il faut tirer aléatoirement un point de départ dans `train_data` et extraire les `block_size` caractères suivants. Lors du tirage du point de départ, faire attention à laisser suffisamment de caractères après le point de départ pour avoir une séquence de `block_size` caractères.
#
# Questions :
# > * Créer les batchs `x` en tirant `batch_size` séquences de longeur `block_size` à  partir d'un point `i` tiré aléatoirement. Empiler les exemples avec `torch.stack`.
# > * Créer les batchs `y` en ajoutant le caractère suivant la séquence `x`. Empiler les exemples avec `torch.stack`.

# %%
batch_size = 4
torch.manual_seed(2023)
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
# data loading
def get_batch(split):
    # generate a small batch of data of inputs x and targets y
    data = train_data if split == 'train' else val_data
    data_len=len(data)
    ## YOUR CODE HERE
    # select batch_size starting points in the data, store them in a list called starting_points
    starting_points = torch.randint(0, data_len - block_size, (batch_size,))
    
    # x is the sequence of integer starting at each straing point and of length block_size
    # y is the character after each starting position
    x_list = []
    y_list = []
    for start in starting_points:
        x_seq = data[start:start + block_size]
        y_seq = data[start + 1:start + block_size + 1]
        x_list.append(x_seq)
        y_list.append(y_seq)

    ### 
    x = torch.stack(x_list)
    y = torch.stack(y_list)
    # send data and target to device
    x, y = x.to(device), y.to(device)
    return x, y

# %% [markdown]
# ### Premier modèle : un bigramme
#
# Le premier modèle que nous allons implémenter est un modèle bigramme. Il prédit le caractère suivant uniquement en fonction du caractère courant. Il est possible de stocker ce modèle dans une simple matrice : pour chaque caractère (en ligne), on stocke la distribution de probabilités sur l'ensemble des caractères suivants (en colonne). On peut donc le stocker dans une simple couche [`Embedding`](https://pytorch.org/docs/stable/generated/torch.nn.Embedding.html).
#
# Questions :
# > * Dans le constructeur, définir une couche Embedding de taille `vocab_size` par `vocab_size`.
# > * Dans forward, appliquer la couche d'embedding au batch de idx (`x`).
# > * Dans forward, définir la loss comme la `cross_entropy` entre la prédiction et target (`y`).

# %%
import torch.nn as nn

# use a gpu if we have one
device = 'cuda' if torch.cuda.is_available() else 'cpu'

# Simple bigram model
class BigramLanguageModel(nn.Module):

    def __init__(self, vocab_size):
        super().__init__()
        # we use a simple vocab_size times vocab_size tensor to store the probabilities 
        # of each token given a single token as context in nn.Embedding
        # YOUR CODE HERE
        self.token_embedding_table = nn.Embedding(vocab_size, vocab_size)
        ## 
        
    def forward(self, idx, targets=None):

        # idx and targets are both (Batch,Time) tensor of integers
        # YOUR CODE HERE
        logits = self.token_embedding_table(idx)

        ## 
   
        # don't compute loss if we don't have targets
        if targets is None:
            loss = None
        else:
            # change the shape of the logits and target to match what is needed for CrossEntropyLoss
            # https://pytorch.org/docs/stable/generated/torch.nn.CrossEntropyLoss.html
            Batch, Time, Channels = logits.shape
            logits = logits.view(Batch*Time, Channels)
            targets = targets.view(Batch*Time)
            
            # negative log likelihood between prediction and target
            # YOUR CODE HERE
            loss = nn.functional.cross_entropy(logits, targets)

            ## 

        return logits, loss

    def generate(self, idx, max_new_tokens):
        # idx is (B, T) array of indices in the current context
        for _ in range(max_new_tokens):
            # get the predictions
            logits, loss = self(idx)
            # focus only on the last time step
            logits = logits[:, -1, :] # becomes (B, C)
            # apply softmax to get probabilities
            probs = nn.functional.softmax(logits, dim=-1) # (B, C)
            # sample from the distribution
            idx_next = torch.multinomial(probs, num_samples=1) # (B, 1)
            # append sampled index to the running sequence
            idx = torch.cat((idx, idx_next), dim=1) # (B, T+1)
        return idx

model = BigramLanguageModel(vocab_size)
# send the model to device
m = model.to(device)

# %% [markdown]
# #### Modèle avant entraînement
# Le modèle n'a pas encore été entrainé, il est juste initialisé, mais on peut calculer la loss sur un batch aléatoire. Les poids étant initialisés avec une distribution normale N(0,1) sur chaque dimension, la loss attendue après l'initialisation devrait être proche de `-ln(1/vocab_size)` (l'entropie est maximale).

# %%
import math
xb, yb = get_batch('train')
logits, loss = m(xb, yb)
print (logits.shape)
print (f'loss attendue {-math.log(1.0/vocab_size)}')
print (f'loss calculée {loss}')
# Out:
# torch.Size([32, 101])
# loss attendue 4.61512051684126
# loss calculée 4.87128210067749

# %% [markdown]
# Pour utiliser le modèle en prédiction, il faut lui fournir un premier caractère pour amorcer la séquence : c'est le prompt. Dans notre cas, on peut initialiser la génération avec le caractère de retour à la ligne pour débuter une nouvelle phrase.
#
# Questions :
# > * Créer un prompt avec un tenseur de taille (1,1) contenant l'entier correspondant au caractère `\n`.
# > * Générer une séquence de caractères de taille 100 à partir de ce prompt avec les fonctions `m.generate` et `decode`.
# > * Comment est la phrase générée ?

# %%
print (encode(['\n']))
## YOUR CODE HERE
#  le prompt initial
newline_char_code = 100  # Code ASCII pour '\n'
prompt = torch.tensor([[newline_char_code]], dtype=torch.long).to(device)
# Génération la séquence de 100 caractères
generated_indices = m.generate(prompt, max_new_tokens=100)

# decode la séquence générée
generated_text = decode(generated_indices[0].tolist())
print(generated_text)

###
# Out:
# [0]
# ûS·X:B;u2»lX'G-hR-E»GuSÂFëh tU'fXÊjdb7èyî56ÊëçmLX8yK«07û;ueÊ3;ÀCÀÎBGB»gbÂÆYBcêWrË:9-hNèrEV«»Uu(WZ ,WE

# %% [markdown]
# ### Entrainement
#
# Pour l'entrainement, nous utilisons un optimiseur [AdamW](https://pytorch.org/docs/stable/generated/torch.optim.AdamW.html) avec un learning rate de 1e-3. Une itération d'apprentissage consiste en
# - générer un batch
# - appliquer le réseau de neurones (forward) et calculer la loss (`model(xb, yb)`)
# - calculer le gradient (après avoir remis à zero le gradient cumulé) (`loss.backward()`)
# - mettre à jour les paramètres (`optimizer.step()`).

# %%
max_iters = 100
batch_size = 4
eval_interval = 10
learning_rate = 1e-3
eval_iters = 20

@torch.no_grad() # no gradient is computed here
def estimate_loss():
    """ Estimate the loss on eval_iters batch of train and val sets."""
    out = {}
    model.eval()
    for split in ['train', 'val']:
        losses = torch.zeros(eval_iters)
        for k in range(eval_iters):
            X, Y = get_batch(split)
            logits, loss = model(X, Y)
            losses[k] = loss.item()
        out[split] = losses.mean()
    model.train()
    return out

# re-create the model
model = BigramLanguageModel(vocab_size)
m = model.to(device)

# create a PyTorch optimizer
optimizer = torch.optim.AdamW(model.parameters(), lr=learning_rate)

for iter in range(max_iters):

    # every once in a while evaluate the loss on train and val sets
    if iter % eval_interval == 0:
        losses = estimate_loss()
        print(f"step {iter}: train loss {losses['train']:.4f}, val loss {losses['val']:.4f}")

    # sample a batch of data
    xb, yb = get_batch('train')

    # evaluate the loss
    logits, loss = m(xb, yb)
    optimizer.zero_grad(set_to_none=True)
    loss.backward()
    optimizer.step()
# Out:
# step 0: train loss 4.8717, val loss 5.0225
# step 10: train loss 4.9009, val loss 4.9663
# step 20: train loss 4.9277, val loss 4.9504
# step 30: train loss 4.8989, val loss 4.9776
# step 40: train loss 4.8667, val loss 4.9980
# step 50: train loss 4.9045, val loss 4.9832
# step 60: train loss 4.9071, val loss 5.0338
# step 70: train loss 4.8695, val loss 5.0400
# step 80: train loss 4.8456, val loss 4.8420
# step 90: train loss 4.8983, val loss 4.9423

# %% [markdown]
# Une fois le réseau entrainé pendant 100 itérations, on peut générer une séquence de caractères.
#
# Questions :
# > * Quel est l'effet de l'entraînement ?
# > * Augmenter le nombre d'itérations à 1000 puis à 10,000, noter la loss obtenue et la phrase générée. Qu'observez-vous ?

# %%
max_iters=1000
for iter in range(max_iters):

    # every once in a while evaluate the loss on train and val sets
    if iter % eval_interval == 0:
        losses = estimate_loss()
        print(f"step {iter}: train loss {losses['train']:.4f}, val loss {losses['val']:.4f}")

    # sample a batch of data
    xb, yb = get_batch('train')

    # evaluate the loss
    logits, loss = m(xb, yb)
    optimizer.zero_grad(set_to_none=True)
    loss.backward()
    optimizer.step()
# Out:
# step 0: train loss 4.8650, val loss 4.9508
# step 10: train loss 4.8160, val loss 4.9477
# step 20: train loss 4.7904, val loss 4.8840
# step 30: train loss 4.7969, val loss 4.8855
# step 40: train loss 4.8067, val loss 4.8680
# step 50: train loss 4.8017, val loss 4.8618
# step 60: train loss 4.6901, val loss 4.9335
# step 70: train loss 4.7938, val loss 4.7730
# step 80: train loss 4.7108, val loss 4.8237
# step 90: train loss 4.7469, val loss 4.9137
# step 100: train loss 4.7328, val loss 4.8738
# step 110: train loss 4.7377, val loss 4.8978
# step 120: train loss 4.6909, val loss 4.9682
# step 130: train loss 4.6662, val loss 4.8040
# step 140: train loss 4.6198, val loss 4.7778
# step 150: train loss 4.6633, val loss 4.8052
# step 160: train loss 4.7182, val loss 4.7064
# step 170: train loss 4.7049, val loss 4.8191
# step 180: train loss 4.6808, val loss 4.7833
# step 190: train loss 4.7259, val loss 4.7871
# step 200: train loss 4.6241, val loss 4.6617
# step 210: train loss 4.6895, val loss 4.7454
# step 220: train loss 4.6285, val loss 4.8023
# step 230: train loss 4.6672, val loss 4.7651
# step 240: train loss 4.6218, val loss 4.6691
# step 250: train loss 4.5874, val loss 4.7037
# step 260: train loss 4.6175, val loss 4.6941
# step 270: train loss 4.5529, val loss 4.7067
# step 280: train loss 4.5932, val loss 4.7157
# step 290: train loss 4.5543, val loss 4.6998
# step 300: train loss 4.5980, val loss 4.6557
# step 310: train loss 4.5501, val loss 4.6397
# step 320: train loss 4.5159, val loss 4.6186
# step 330: train loss 4.5889, val loss 4.6504
# step 340: train loss 4.5086, val loss 4.7025
# step 350: train loss 4.5751, val loss 4.6463
# step 360: train loss 4.5128, val loss 4.7090
# step 370: train loss 4.5285, val loss 4.6127
# step 380: train loss 4.5246, val loss 4.6511
# step 390: train loss 4.5312, val loss 4.6218
# step 400: train loss 4.5509, val loss 4.7037
# step 410: train loss 4.5206, val loss 4.7531
# step 420: train loss 4.5122, val loss 4.6322
# step 430: train loss 4.6221, val loss 4.6492
# step 440: train loss 4.4398, val loss 4.6075
# step 450: train loss 4.4818, val loss 4.5479
# step 460: train loss 4.4748, val loss 4.4865
# step 470: train loss 4.4410, val loss 4.5634
# step 480: train loss 4.4515, val loss 4.5273
# step 490: train loss 4.5125, val loss 4.6682
# step 500: train loss 4.4446, val loss 4.5714
# step 510: train loss 4.3893, val loss 4.4827
# step 520: train loss 4.4561, val loss 4.5638
# step 530: train loss 4.4223, val loss 4.5353
# step 540: train loss 4.4462, val loss 4.5205
# step 550: train loss 4.4028, val loss 4.4653
# step 560: train loss 4.3067, val loss 4.4816
# step 570: train loss 4.4449, val loss 4.5108
# step 580: train loss 4.3469, val loss 4.4797
# step 590: train loss 4.4615, val loss 4.5866
# step 600: train loss 4.3838, val loss 4.4509
# step 610: train loss 4.3459, val loss 4.4826
# step 620: train loss 4.3761, val loss 4.5053
# step 630: train loss 4.3699, val loss 4.4278
# step 640: train loss 4.3461, val loss 4.3506
# step 650: train loss 4.4248, val loss 4.4447
# step 660: train loss 4.2642, val loss 4.4451
# step 670: train loss 4.2989, val loss 4.4777
# step 680: train loss 4.2441, val loss 4.5949
# step 690: train loss 4.2384, val loss 4.3982
# step 700: train loss 4.2735, val loss 4.3975
# step 710: train loss 4.1664, val loss 4.3672
# step 720: train loss 4.3141, val loss 4.5203
# step 730: train loss 4.2586, val loss 4.4327
# step 740: train loss 4.1774, val loss 4.3584
# step 750: train loss 4.3765, val loss 4.3505
# step 760: train loss 4.2822, val loss 4.3659
# step 770: train loss 4.1547, val loss 4.2907
# step 780: train loss 4.2722, val loss 4.3794
# step 790: train loss 4.2517, val loss 4.4116
# step 800: train loss 4.1690, val loss 4.2702
# step 810: train loss 4.2027, val loss 4.2856
# step 820: train loss 4.2293, val loss 4.3386
# step 830: train loss 4.2377, val loss 4.3292
# step 840: train loss 4.1335, val loss 4.2936
# step 850: train loss 4.1540, val loss 4.2548
# step 860: train loss 4.1692, val loss 4.2876
# step 870: train loss 4.1971, val loss 4.3304
# step 880: train loss 4.1884, val loss 4.2238
# step 890: train loss 4.1166, val loss 4.2747
# step 900: train loss 4.1478, val loss 4.3481
# step 910: train loss 4.1776, val loss 4.3552
# step 920: train loss 4.1687, val loss 4.2542
# step 930: train loss 4.1088, val loss 4.1157
# step 940: train loss 4.1101, val loss 4.2632
# step 950: train loss 4.1267, val loss 4.3919
# step 960: train loss 4.1324, val loss 4.2063
# step 970: train loss 4.1475, val loss 4.2927
# step 980: train loss 4.0443, val loss 4.3312
# step 990: train loss 4.1070, val loss 4.2401

# %%
max_iters=10000
for iter in range(max_iters):

    # every once in a while evaluate the loss on train and val sets
    if iter % eval_interval == 0:
        losses = estimate_loss()
        print(f"step {iter}: train loss {losses['train']:.4f}, val loss {losses['val']:.4f}")

    # sample a batch of data
    xb, yb = get_batch('train')

    # evaluate the loss
    logits, loss = m(xb, yb)
    optimizer.zero_grad(set_to_none=True)
    loss.backward()
    optimizer.step()
# Out:
# step 0: train loss 4.0778, val loss 4.2505
# step 10: train loss 4.1174, val loss 4.1878
# step 20: train loss 4.0888, val loss 4.2132
# step 30: train loss 4.0299, val loss 4.1802
# step 40: train loss 4.0360, val loss 4.0778
# step 50: train loss 4.0644, val loss 4.2081
# step 60: train loss 3.9893, val loss 4.1738
# step 70: train loss 4.0772, val loss 4.1078
# step 80: train loss 3.9899, val loss 4.2483
# step 90: train loss 4.0323, val loss 4.1886
# step 100: train loss 4.0532, val loss 4.1688
# step 110: train loss 4.0167, val loss 4.2263
# step 120: train loss 4.0494, val loss 4.0567
# step 130: train loss 4.0354, val loss 4.1471
# step 140: train loss 4.0321, val loss 4.1793
# step 150: train loss 3.9817, val loss 4.1565
# step 160: train loss 4.0442, val loss 4.1635
# step 170: train loss 3.9799, val loss 4.0894
# step 180: train loss 3.9342, val loss 4.0778
# step 190: train loss 4.0771, val loss 4.2122
# step 200: train loss 3.9332, val loss 4.1919
# step 210: train loss 3.9836, val loss 4.1061
# step 220: train loss 3.9300, val loss 4.1022
# step 230: train loss 3.9601, val loss 4.0727
# step 240: train loss 3.9121, val loss 4.0042
# step 250: train loss 3.9624, val loss 4.1299
# step 260: train loss 3.9277, val loss 4.0265
# step 270: train loss 4.0356, val loss 3.9889
# step 280: train loss 3.9837, val loss 4.0790
# step 290: train loss 3.8734, val loss 4.0762
# step 300: train loss 3.8768, val loss 4.0418
# step 310: train loss 3.9888, val loss 4.0986
# step 320: train loss 3.8924, val loss 3.9220
# step 330: train loss 3.8977, val loss 4.0461
# step 340: train loss 3.9177, val loss 3.8742
# step 350: train loss 3.9631, val loss 4.0324
# step 360: train loss 3.8547, val loss 4.0606
# step 370: train loss 3.7678, val loss 4.0589
# step 380: train loss 3.8021, val loss 3.9514
# step 390: train loss 3.8452, val loss 3.8862
# step 400: train loss 3.9075, val loss 4.0132
# step 410: train loss 3.8802, val loss 4.0614
# step 420: train loss 3.8285, val loss 3.9396
# step 430: train loss 3.8161, val loss 4.0208
# step 440: train loss 3.8216, val loss 3.9280
# step 450: train loss 3.8395, val loss 3.9791
# step 460: train loss 3.9360, val loss 3.8364
# step 470: train loss 3.8358, val loss 3.9124
# step 480: train loss 3.8207, val loss 3.9899
# step 490: train loss 3.8081, val loss 3.9771
# step 500: train loss 3.8256, val loss 3.9490
# step 510: train loss 3.8244, val loss 4.0026
# step 520: train loss 3.7688, val loss 3.9109
# step 530: train loss 3.8111, val loss 3.9220
# step 540: train loss 3.8274, val loss 3.9792
# step 550: train loss 3.7732, val loss 3.9016
# step 560: train loss 3.7776, val loss 3.9649
# step 570: train loss 3.7674, val loss 3.8873
# step 580: train loss 3.7880, val loss 3.9692
# step 590: train loss 3.7291, val loss 3.8643
# step 600: train loss 3.7519, val loss 3.8492
# step 610: train loss 3.7300, val loss 3.9469
# step 620: train loss 3.8015, val loss 3.8977
# step 630: train loss 3.7179, val loss 3.9217
# step 640: train loss 3.6390, val loss 3.9102
# step 650: train loss 3.7230, val loss 3.8527
# step 660: train loss 3.8016, val loss 3.9319
# step 670: train loss 3.7175, val loss 3.8599
# step 680: train loss 3.6597, val loss 3.8890
# step 690: train loss 3.6510, val loss 3.9322
# step 700: train loss 3.7419, val loss 3.8420
# step 710: train loss 3.6904, val loss 3.9440
# step 720: train loss 3.7284, val loss 3.8274
# step 730: train loss 3.6905, val loss 3.7070
# step 740: train loss 3.6418, val loss 3.8224
# step 750: train loss 3.6315, val loss 3.7754
# step 760: train loss 3.6527, val loss 3.9513
# step 770: train loss 3.6207, val loss 3.9685
# step 780: train loss 3.6710, val loss 3.9737
# step 790: train loss 3.6321, val loss 3.8678
# step 800: train loss 3.6270, val loss 3.7389
# step 810: train loss 3.6493, val loss 3.8138
# step 820: train loss 3.7501, val loss 3.8646
# step 830: train loss 3.6558, val loss 3.8129
# step 840: train loss 3.5789, val loss 3.7998
# step 850: train loss 3.7564, val loss 3.8963
# step 860: train loss 3.6400, val loss 3.7920
# step 870: train loss 3.6163, val loss 3.7414
# step 880: train loss 3.5913, val loss 3.8115
# step 890: train loss 3.5714, val loss 3.7657
# step 900: train loss 3.6836, val loss 3.6910
# step 910: train loss 3.5659, val loss 3.6629
# step 920: train loss 3.5964, val loss 3.6217
# step 930: train loss 3.6430, val loss 3.8201
# step 940: train loss 3.6178, val loss 3.7258
# step 950: train loss 3.5209, val loss 3.7594
# step 960: train loss 3.5548, val loss 3.7315
# step 970: train loss 3.5217, val loss 3.7403
# step 980: train loss 3.5844, val loss 3.8358
# step 990: train loss 3.5407, val loss 3.6115
# step 1000: train loss 3.5676, val loss 3.7051
# step 1010: train loss 3.6520, val loss 3.7040
# step 1020: train loss 3.5135, val loss 3.7308
# step 1030: train loss 3.6588, val loss 3.6784
# step 1040: train loss 3.6289, val loss 3.7242
# step 1050: train loss 3.5260, val loss 3.7113
# step 1060: train loss 3.4453, val loss 3.6348
# step 1070: train loss 3.5987, val loss 3.6771
# step 1080: train loss 3.5412, val loss 3.7194
# step 1090: train loss 3.4696, val loss 3.7282
# step 1100: train loss 3.6189, val loss 3.6483
# step 1110: train loss 3.4651, val loss 3.7091
# step 1120: train loss 3.5012, val loss 3.6304
# step 1130: train loss 3.5014, val loss 3.5049
# step 1140: train loss 3.5570, val loss 3.6804
# step 1150: train loss 3.4512, val loss 3.6852
# step 1160: train loss 3.3586, val loss 3.5676
# step 1170: train loss 3.4032, val loss 3.6306
# step 1180: train loss 3.4561, val loss 3.6137
# step 1190: train loss 3.4134, val loss 3.7087
# step 1200: train loss 3.4825, val loss 3.7441
# step 1210: train loss 3.5815, val loss 3.5811
# step 1220: train loss 3.4414, val loss 3.7528
# step 1230: train loss 3.4490, val loss 3.5065
# step 1240: train loss 3.4115, val loss 3.5724
# step 1250: train loss 3.4402, val loss 3.5460
# step 1260: train loss 3.4451, val loss 3.4929
# step 1270: train loss 3.4976, val loss 3.6708
# step 1280: train loss 3.5315, val loss 3.6008
# step 1290: train loss 3.4342, val loss 3.7461
# step 1300: train loss 3.4133, val loss 3.5459
# step 1310: train loss 3.5470, val loss 3.6337
# step 1320: train loss 3.4194, val loss 3.5917
# step 1330: train loss 3.4089, val loss 3.4454
# step 1340: train loss 3.4703, val loss 3.5844
# step 1350: train loss 3.4256, val loss 3.5694
# step 1360: train loss 3.3658, val loss 3.5712
# step 1370: train loss 3.4403, val loss 3.4813
# step 1380: train loss 3.4967, val loss 3.6259
# step 1390: train loss 3.3513, val loss 3.6444
# step 1400: train loss 3.4405, val loss 3.5530
# step 1410: train loss 3.3357, val loss 3.5640
# step 1420: train loss 3.4579, val loss 3.5455
# step 1430: train loss 3.3966, val loss 3.5846
# step 1440: train loss 3.4018, val loss 3.4813
# step 1450: train loss 3.4120, val loss 3.5176
# step 1460: train loss 3.3807, val loss 3.5359
# step 1470: train loss 3.2975, val loss 3.4747
# step 1480: train loss 3.3739, val loss 3.5581
# step 1490: train loss 3.3683, val loss 3.5671
# step 1500: train loss 3.2826, val loss 3.5007
# step 1510: train loss 3.3517, val loss 3.4762
# step 1520: train loss 3.3405, val loss 3.5251
# step 1530: train loss 3.4105, val loss 3.4893
# step 1540: train loss 3.4148, val loss 3.4630
# step 1550: train loss 3.3545, val loss 3.5577
# step 1560: train loss 3.3034, val loss 3.4480
# step 1570: train loss 3.3549, val loss 3.5292
# step 1580: train loss 3.3948, val loss 3.4218
# step 1590: train loss 3.3908, val loss 3.4796
# step 1600: train loss 3.4076, val loss 3.4842
# step 1610: train loss 3.3651, val loss 3.3781
# step 1620: train loss 3.3249, val loss 3.5515
# step 1630: train loss 3.3903, val loss 3.4528
# step 1640: train loss 3.3421, val loss 3.5325
# step 1650: train loss 3.2441, val loss 3.5820
# step 1660: train loss 3.2746, val loss 3.5609
# step 1670: train loss 3.3264, val loss 3.3975
# step 1680: train loss 3.2908, val loss 3.3895
# step 1690: train loss 3.2314, val loss 3.4795
# step 1700: train loss 3.2931, val loss 3.4721
# step 1710: train loss 3.2046, val loss 3.3487
# step 1720: train loss 3.2695, val loss 3.4576
# step 1730: train loss 3.2027, val loss 3.5346
# step 1740: train loss 3.3074, val loss 3.5709
# step 1750: train loss 3.3018, val loss 3.4286
# step 1760: train loss 3.3052, val loss 3.4363
# step 1770: train loss 3.2490, val loss 3.3701
# step 1780: train loss 3.2991, val loss 3.4886
# step 1790: train loss 3.2254, val loss 3.2880
# step 1800: train loss 3.2474, val loss 3.5451
# step 1810: train loss 3.1749, val loss 3.3695
# step 1820: train loss 3.2284, val loss 3.4290
# step 1830: train loss 3.1941, val loss 3.4297
# step 1840: train loss 3.2279, val loss 3.3882
# step 1850: train loss 3.2237, val loss 3.2808
# step 1860: train loss 3.2488, val loss 3.4579
# step 1870: train loss 3.2551, val loss 3.4045
# step 1880: train loss 3.2201, val loss 3.4779
# step 1890: train loss 3.2114, val loss 3.3376
# step 1900: train loss 3.2064, val loss 3.3061
# step 1910: train loss 3.1755, val loss 3.4401
# step 1920: train loss 3.2672, val loss 3.4994
# step 1930: train loss 3.2621, val loss 3.3425
# step 1940: train loss 3.1554, val loss 3.3867
# step 1950: train loss 3.1769, val loss 3.3968
# step 1960: train loss 3.2377, val loss 3.3955
# step 1970: train loss 3.2532, val loss 3.3560
# step 1980: train loss 3.1734, val loss 3.5028
# step 1990: train loss 3.2322, val loss 3.3832
# step 2000: train loss 3.2072, val loss 3.4045
# step 2010: train loss 3.1667, val loss 3.4002
# step 2020: train loss 3.2632, val loss 3.3363
# step 2030: train loss 3.1485, val loss 3.4024
# step 2040: train loss 3.1153, val loss 3.3241
# step 2050: train loss 3.2098, val loss 3.3287
# step 2060: train loss 3.1997, val loss 3.3030
# step 2070: train loss 3.2063, val loss 3.3376
# step 2080: train loss 3.2443, val loss 3.2666
# step 2090: train loss 3.2103, val loss 3.3194
# step 2100: train loss 3.1096, val loss 3.3589
# step 2110: train loss 3.1283, val loss 3.4391
# step 2120: train loss 3.2093, val loss 3.3058
# step 2130: train loss 3.1262, val loss 3.2237
# step 2140: train loss 3.0870, val loss 3.2482
# step 2150: train loss 3.1437, val loss 3.2490
# step 2160: train loss 3.1480, val loss 3.2996
# step 2170: train loss 3.1250, val loss 3.2187
# step 2180: train loss 3.1972, val loss 3.3017
# step 2190: train loss 3.1168, val loss 3.3209
# step 2200: train loss 3.1593, val loss 3.4026
# step 2210: train loss 3.1214, val loss 3.3611
# step 2220: train loss 3.0975, val loss 3.4147
# step 2230: train loss 3.1416, val loss 3.2406
# step 2240: train loss 3.1182, val loss 3.2983
# step 2250: train loss 3.1640, val loss 3.3512
# step 2260: train loss 3.1787, val loss 3.2676
# step 2270: train loss 3.0471, val loss 3.3318
# step 2280: train loss 3.1200, val loss 3.3224
# step 2290: train loss 3.0348, val loss 3.3475
# step 2300: train loss 3.1065, val loss 3.1460
# step 2310: train loss 3.1330, val loss 3.3951
# step 2320: train loss 3.1297, val loss 3.1889
# step 2330: train loss 3.1322, val loss 3.3330
# step 2340: train loss 3.1364, val loss 3.3088
# step 2350: train loss 3.1392, val loss 3.2258
# step 2360: train loss 3.1246, val loss 3.1858
# step 2370: train loss 3.0404, val loss 3.3026
# step 2380: train loss 3.1465, val loss 3.1622
# step 2390: train loss 3.0846, val loss 3.2236
# step 2400: train loss 3.0953, val loss 3.3137
# step 2410: train loss 3.1552, val loss 3.1247
# step 2420: train loss 3.0772, val loss 3.1980
# step 2430: train loss 3.1257, val loss 3.3621
# step 2440: train loss 3.0919, val loss 3.1915
# step 2450: train loss 3.0747, val loss 3.1659
# step 2460: train loss 3.0216, val loss 3.2443
# step 2470: train loss 3.1078, val loss 3.1877
# step 2480: train loss 3.1552, val loss 3.2048
# step 2490: train loss 3.1446, val loss 3.1304
# step 2500: train loss 3.0789, val loss 3.1565
# step 2510: train loss 3.0461, val loss 3.2344
# step 2520: train loss 3.0373, val loss 3.2206
# step 2530: train loss 3.0881, val loss 3.2976
# step 2540: train loss 3.1039, val loss 3.2422
# step 2550: train loss 3.0437, val loss 3.1288
# step 2560: train loss 3.0518, val loss 3.2950
# step 2570: train loss 3.0526, val loss 3.2658
# step 2580: train loss 3.1151, val loss 3.3346
# step 2590: train loss 3.0881, val loss 3.1847
# step 2600: train loss 3.0130, val loss 3.2128
# step 2610: train loss 2.9920, val loss 3.2170
# step 2620: train loss 3.1215, val loss 3.1370
# step 2630: train loss 3.1380, val loss 3.2716
# step 2640: train loss 3.0763, val loss 3.3310
# step 2650: train loss 3.0318, val loss 3.2122
# step 2660: train loss 3.0364, val loss 3.0831
# step 2670: train loss 3.0211, val loss 3.1894
# step 2680: train loss 3.0649, val loss 3.1381
# step 2690: train loss 2.9489, val loss 3.3318
# step 2700: train loss 3.0687, val loss 3.1394
# step 2710: train loss 3.1141, val loss 3.1271
# step 2720: train loss 3.0465, val loss 3.1581
# step 2730: train loss 3.0027, val loss 3.1316
# step 2740: train loss 3.0291, val loss 3.2012
# step 2750: train loss 3.0153, val loss 3.0689
# step 2760: train loss 2.9788, val loss 3.0870
# step 2770: train loss 3.0764, val loss 3.1271
# step 2780: train loss 2.9938, val loss 3.1575
# step 2790: train loss 2.9963, val loss 3.1540
# step 2800: train loss 3.0242, val loss 3.1706
# step 2810: train loss 3.0035, val loss 3.2991
# step 2820: train loss 3.0496, val loss 3.2059
# step 2830: train loss 3.0235, val loss 3.2029
# step 2840: train loss 2.9584, val loss 3.2251
# step 2850: train loss 3.0184, val loss 2.9996
# step 2860: train loss 2.9956, val loss 3.1338
# step 2870: train loss 2.9310, val loss 3.3072
# step 2880: train loss 2.9955, val loss 3.1653
# step 2890: train loss 2.9033, val loss 3.1691
# step 2900: train loss 2.9586, val loss 3.2339
# step 2910: train loss 2.9944, val loss 3.0816
# step 2920: train loss 2.9440, val loss 3.1844
# step 2930: train loss 2.9553, val loss 3.0602
# step 2940: train loss 2.9981, val loss 3.1198
# step 2950: train loss 3.0386, val loss 3.1709
# step 2960: train loss 2.8961, val loss 3.1975
# step 2970: train loss 3.0176, val loss 3.0700
# step 2980: train loss 2.9892, val loss 3.1882
# step 2990: train loss 2.9040, val loss 3.2498
# step 3000: train loss 2.9868, val loss 3.2227
# step 3010: train loss 3.0098, val loss 3.0601
# step 3020: train loss 3.0651, val loss 3.1888
# step 3030: train loss 2.9237, val loss 3.0833
# step 3040: train loss 2.9801, val loss 2.9905
# step 3050: train loss 2.9016, val loss 3.1564
# step 3060: train loss 2.9037, val loss 3.0300
# step 3070: train loss 2.9593, val loss 3.1741
# step 3080: train loss 2.8966, val loss 3.1859
# step 3090: train loss 3.0736, val loss 2.9982
# step 3100: train loss 2.9280, val loss 3.1942
# step 3110: train loss 3.0118, val loss 2.9870
# step 3120: train loss 2.9451, val loss 3.0120
# step 3130: train loss 2.9295, val loss 3.0442
# step 3140: train loss 2.9565, val loss 3.0956
# step 3150: train loss 2.9125, val loss 3.0593
# step 3160: train loss 2.8822, val loss 3.2233
# step 3170: train loss 2.9807, val loss 3.1844
# step 3180: train loss 2.9496, val loss 3.1547
# step 3190: train loss 2.8947, val loss 3.0846
# step 3200: train loss 2.9256, val loss 3.0756
# step 3210: train loss 2.8610, val loss 3.1093
# step 3220: train loss 3.0132, val loss 3.0418
# step 3230: train loss 2.9217, val loss 3.1874
# step 3240: train loss 2.9229, val loss 3.1371
# step 3250: train loss 2.9635, val loss 3.0534
# step 3260: train loss 2.9117, val loss 3.1181
# step 3270: train loss 2.9348, val loss 3.0262
# step 3280: train loss 2.9231, val loss 3.1066
# step 3290: train loss 2.9919, val loss 3.1031
# step 3300: train loss 2.8967, val loss 3.0569
# step 3310: train loss 2.9792, val loss 3.0229
# step 3320: train loss 2.8567, val loss 3.0711
# step 3330: train loss 2.8526, val loss 3.0399
# step 3340: train loss 2.9265, val loss 3.0764
# step 3350: train loss 2.8433, val loss 2.9844
# step 3360: train loss 2.8901, val loss 3.0657
# step 3370: train loss 2.9773, val loss 3.0265
# step 3380: train loss 2.8837, val loss 2.9201
# step 3390: train loss 2.8154, val loss 3.0915
# step 3400: train loss 2.9439, val loss 3.1005
# step 3410: train loss 2.8109, val loss 2.9686
# step 3420: train loss 2.8414, val loss 3.0016
# step 3430: train loss 2.8632, val loss 3.0027
# step 3440: train loss 2.9248, val loss 3.0566
# step 3450: train loss 2.9288, val loss 2.9065
# step 3460: train loss 2.9345, val loss 3.0274
# step 3470: train loss 2.8797, val loss 2.9270
# step 3480: train loss 2.8381, val loss 3.0282
# step 3490: train loss 2.9048, val loss 3.0669
# step 3500: train loss 2.8192, val loss 3.0342
# step 3510: train loss 2.8920, val loss 2.9915
# step 3520: train loss 2.9031, val loss 3.0149
# step 3530: train loss 2.7934, val loss 3.0029
# step 3540: train loss 2.8869, val loss 2.9931
# step 3550: train loss 2.9330, val loss 3.0773
# step 3560: train loss 2.9242, val loss 3.1232
# step 3570: train loss 2.8961, val loss 3.0716
# step 3580: train loss 2.8674, val loss 2.9493
# step 3590: train loss 2.8710, val loss 3.0576
# step 3600: train loss 2.8787, val loss 3.0328
# step 3610: train loss 2.8755, val loss 3.0114
# step 3620: train loss 2.9166, val loss 2.9559
# step 3630: train loss 2.8356, val loss 3.1058
# step 3640: train loss 2.8244, val loss 2.9876
# step 3650: train loss 2.8299, val loss 2.8105
# step 3660: train loss 2.8767, val loss 2.9539
# step 3670: train loss 2.8431, val loss 2.9974
# step 3680: train loss 2.8055, val loss 2.9184
# step 3690: train loss 2.7541, val loss 3.0634
# step 3700: train loss 2.7927, val loss 2.8967
# step 3710: train loss 2.8230, val loss 3.0186
# step 3720: train loss 2.9041, val loss 2.9988
# step 3730: train loss 2.8877, val loss 2.8646
# step 3740: train loss 2.8249, val loss 2.9727
# step 3750: train loss 2.7354, val loss 3.0550
# step 3760: train loss 2.7789, val loss 2.8566
# step 3770: train loss 2.8363, val loss 2.9562
# step 3780: train loss 2.7844, val loss 3.1521
# step 3790: train loss 2.8901, val loss 2.9748
# step 3800: train loss 2.7562, val loss 2.9082
# step 3810: train loss 2.8614, val loss 2.9396
# step 3820: train loss 2.8211, val loss 2.9688
# step 3830: train loss 2.8628, val loss 2.9765
# step 3840: train loss 2.8206, val loss 2.8809
# step 3850: train loss 2.7891, val loss 2.9792
# step 3860: train loss 2.7302, val loss 3.0132
# step 3870: train loss 2.8219, val loss 2.9454
# step 3880: train loss 2.8451, val loss 2.9169
# step 3890: train loss 2.8664, val loss 3.0145
# step 3900: train loss 2.8156, val loss 2.8951
# step 3910: train loss 2.8143, val loss 3.1148
# step 3920: train loss 2.7453, val loss 2.9463
# step 3930: train loss 2.7623, val loss 2.9468
# step 3940: train loss 2.8813, val loss 2.9389
# step 3950: train loss 2.9393, val loss 3.0743
# step 3960: train loss 2.7839, val loss 2.8595
# step 3970: train loss 2.7869, val loss 2.9409
# step 3980: train loss 2.8479, val loss 2.9942
# step 3990: train loss 2.7439, val loss 3.0007
# step 4000: train loss 2.7338, val loss 2.9593
# step 4010: train loss 2.7482, val loss 2.9903
# step 4020: train loss 2.8669, val loss 2.9098
# step 4030: train loss 2.7556, val loss 2.9073
# step 4040: train loss 2.7013, val loss 2.8517
# step 4050: train loss 2.7855, val loss 2.8387
# step 4060: train loss 2.8248, val loss 2.8910
# step 4070: train loss 2.7572, val loss 2.9516
# step 4080: train loss 2.8021, val loss 2.9318
# step 4090: train loss 2.7955, val loss 3.1806
# step 4100: train loss 2.7504, val loss 2.8971
# step 4110: train loss 2.8059, val loss 3.0256
# step 4120: train loss 2.7900, val loss 2.9927
# step 4130: train loss 2.8346, val loss 2.9873
# step 4140: train loss 2.7889, val loss 2.9053
# step 4150: train loss 2.8030, val loss 2.9011
# step 4160: train loss 2.7511, val loss 2.9677
# step 4170: train loss 2.7600, val loss 2.8754
# step 4180: train loss 2.7661, val loss 3.0112
# step 4190: train loss 2.7898, val loss 2.9170
# step 4200: train loss 2.7278, val loss 2.8839
# step 4210: train loss 2.8126, val loss 2.8745
# step 4220: train loss 2.7729, val loss 2.9420
# step 4230: train loss 2.7736, val loss 2.8972
# step 4240: train loss 2.7611, val loss 2.9005
# step 4250: train loss 2.7723, val loss 2.8971
# step 4260: train loss 2.8575, val loss 2.9486
# step 4270: train loss 2.7234, val loss 3.0399
# step 4280: train loss 2.7693, val loss 3.0350
# step 4290: train loss 2.8058, val loss 2.8628
# step 4300: train loss 2.8359, val loss 2.8569
# step 4310: train loss 2.7686, val loss 2.8944
# step 4320: train loss 2.7611, val loss 2.9046
# step 4330: train loss 2.7148, val loss 2.9913
# step 4340: train loss 2.7424, val loss 2.8677
# step 4350: train loss 2.7645, val loss 2.9968
# step 4360: train loss 2.6713, val loss 2.9384
# step 4370: train loss 2.7874, val loss 2.7849
# step 4380: train loss 2.7181, val loss 2.8354
# step 4390: train loss 2.7859, val loss 2.9821
# step 4400: train loss 2.8896, val loss 3.0380
# step 4410: train loss 2.7041, val loss 2.8848
# step 4420: train loss 2.7770, val loss 2.7645
# step 4430: train loss 2.7013, val loss 2.7862
# step 4440: train loss 2.7003, val loss 2.9438
# step 4450: train loss 2.7040, val loss 2.8442
# step 4460: train loss 2.7641, val loss 2.8975
# step 4470: train loss 2.7032, val loss 2.9509
# step 4480: train loss 2.7480, val loss 2.8451
# step 4490: train loss 2.7110, val loss 2.9061
# step 4500: train loss 2.7216, val loss 2.9019
# step 4510: train loss 2.6852, val loss 2.9481
# step 4520: train loss 2.7425, val loss 2.9232
# step 4530: train loss 2.7820, val loss 2.9526
# step 4540: train loss 2.7045, val loss 2.7624
# step 4550: train loss 2.6185, val loss 2.9104
# step 4560: train loss 2.7705, val loss 2.8657
# step 4570: train loss 2.6819, val loss 2.9880
# step 4580: train loss 2.7692, val loss 2.9001
# step 4590: train loss 2.7387, val loss 2.9436
# step 4600: train loss 2.7022, val loss 2.8972
# step 4610: train loss 2.7420, val loss 2.9476
# step 4620: train loss 2.7595, val loss 2.9653
# step 4630: train loss 2.7145, val loss 2.9501
# step 4640: train loss 2.7997, val loss 3.0302
# step 4650: train loss 2.7025, val loss 2.7105
# step 4660: train loss 2.7807, val loss 2.9441
# step 4670: train loss 2.7885, val loss 3.0631
# step 4680: train loss 2.6590, val loss 3.0001
# step 4690: train loss 2.7055, val loss 2.7892
# step 4700: train loss 2.8462, val loss 2.9264
# step 4710: train loss 2.7185, val loss 2.7841
# step 4720: train loss 2.6677, val loss 2.9818
# step 4730: train loss 2.6893, val loss 2.8774
# step 4740: train loss 2.6935, val loss 2.7754
# step 4750: train loss 2.7178, val loss 2.7545
# step 4760: train loss 2.6331, val loss 2.8508
# step 4770: train loss 2.5518, val loss 2.8646
# step 4780: train loss 2.6835, val loss 2.8412
# step 4790: train loss 2.6450, val loss 2.8279
# step 4800: train loss 2.7429, val loss 2.9303
# step 4810: train loss 2.6419, val loss 2.7493
# step 4820: train loss 2.7501, val loss 2.7231
# step 4830: train loss 2.7198, val loss 2.7337
# step 4840: train loss 2.6986, val loss 2.7191
# step 4850: train loss 2.6660, val loss 2.9252
# step 4860: train loss 2.7206, val loss 2.8959
# step 4870: train loss 2.6709, val loss 2.8538
# step 4880: train loss 2.7480, val loss 2.7165
# step 4890: train loss 2.6479, val loss 2.9190
# step 4900: train loss 2.5854, val loss 2.8474
# step 4910: train loss 2.5707, val loss 2.8927
# step 4920: train loss 2.6666, val loss 2.8743
# step 4930: train loss 2.6150, val loss 3.0005
# step 4940: train loss 2.6968, val loss 2.8759
# step 4950: train loss 2.7587, val loss 2.8077
# step 4960: train loss 2.7080, val loss 2.8379
# step 4970: train loss 2.7414, val loss 2.8480
# step 4980: train loss 2.7118, val loss 2.9557
# step 4990: train loss 2.6785, val loss 2.8444
# step 5000: train loss 2.6417, val loss 2.8123
# step 5010: train loss 2.7355, val loss 2.7126
# step 5020: train loss 2.7575, val loss 2.9222
# step 5030: train loss 2.7584, val loss 2.7420
# step 5040: train loss 2.6435, val loss 2.8199
# step 5050: train loss 2.6375, val loss 2.7793
# step 5060: train loss 2.6270, val loss 2.7992
# step 5070: train loss 2.6098, val loss 2.9019
# step 5080: train loss 2.8026, val loss 2.9704
# step 5090: train loss 2.7436, val loss 2.7964
# step 5100: train loss 2.7012, val loss 2.9073
# step 5110: train loss 2.7094, val loss 2.7564
# step 5120: train loss 2.6609, val loss 2.8504
# step 5130: train loss 2.6916, val loss 2.7099
# step 5140: train loss 2.7228, val loss 2.6711
# step 5150: train loss 2.7413, val loss 2.7905
# step 5160: train loss 2.6580, val loss 2.7984
# step 5170: train loss 2.7676, val loss 2.7327
# step 5180: train loss 2.6011, val loss 2.9061
# step 5190: train loss 2.5958, val loss 2.7969
# step 5200: train loss 2.6500, val loss 2.7403
# step 5210: train loss 2.6556, val loss 2.8407
# step 5220: train loss 2.6196, val loss 2.8873
# step 5230: train loss 2.7644, val loss 2.7621
# step 5240: train loss 2.6774, val loss 2.8222
# step 5250: train loss 2.5870, val loss 2.8274
# step 5260: train loss 2.6331, val loss 2.7297
# step 5270: train loss 2.7358, val loss 2.7482
# step 5280: train loss 2.6579, val loss 2.8151
# step 5290: train loss 2.6156, val loss 2.8258
# step 5300: train loss 2.6921, val loss 2.8208
# step 5310: train loss 2.6646, val loss 2.7758
# step 5320: train loss 2.6594, val loss 2.8273
# step 5330: train loss 2.6299, val loss 2.7807
# step 5340: train loss 2.7143, val loss 2.8299
# step 5350: train loss 2.7238, val loss 2.7667
# step 5360: train loss 2.6984, val loss 2.7622
# step 5370: train loss 2.7346, val loss 2.8233
# step 5380: train loss 2.6759, val loss 2.8274
# step 5390: train loss 2.5569, val loss 2.7787
# step 5400: train loss 2.6753, val loss 2.7057
# step 5410: train loss 2.7095, val loss 2.7426
# step 5420: train loss 2.6193, val loss 2.7662
# step 5430: train loss 2.6999, val loss 2.8253
# step 5440: train loss 2.6868, val loss 2.7398
# step 5450: train loss 2.6480, val loss 2.7458
# step 5460: train loss 2.6561, val loss 2.7470
# step 5470: train loss 2.6390, val loss 2.8192
# step 5480: train loss 2.6713, val loss 2.7858
# step 5490: train loss 2.6472, val loss 2.7950
# step 5500: train loss 2.6031, val loss 2.8282
# step 5510: train loss 2.6109, val loss 2.8303
# step 5520: train loss 2.7355, val loss 2.8424
# step 5530: train loss 2.6753, val loss 2.7791
# step 5540: train loss 2.6194, val loss 2.8598
# step 5550: train loss 2.6834, val loss 2.8648
# step 5560: train loss 2.6521, val loss 2.7985
# step 5570: train loss 2.6443, val loss 2.8537
# step 5580: train loss 2.6662, val loss 2.6802
# step 5590: train loss 2.6363, val loss 2.7787
# step 5600: train loss 2.7455, val loss 2.8947
# step 5610: train loss 2.6278, val loss 2.7362
# step 5620: train loss 2.5618, val loss 2.7249
# step 5630: train loss 2.6083, val loss 2.7447
# step 5640: train loss 2.6341, val loss 2.7492
# step 5650: train loss 2.7105, val loss 2.8084
# step 5660: train loss 2.6722, val loss 2.6749
# step 5670: train loss 2.5660, val loss 2.8367
# step 5680: train loss 2.5955, val loss 2.6943
# step 5690: train loss 2.6421, val loss 2.7374
# step 5700: train loss 2.6358, val loss 2.7549
# step 5710: train loss 2.6676, val loss 2.6772
# step 5720: train loss 2.6490, val loss 2.7027
# step 5730: train loss 2.6871, val loss 2.7780
# step 5740: train loss 2.6860, val loss 2.9251
# step 5750: train loss 2.6526, val loss 2.8917
# step 5760: train loss 2.6146, val loss 2.8467
# step 5770: train loss 2.7289, val loss 2.7702
# step 5780: train loss 2.7267, val loss 2.8334
# step 5790: train loss 2.6462, val loss 2.7931
# step 5800: train loss 2.6945, val loss 2.7333
# step 5810: train loss 2.6419, val loss 2.8005
# step 5820: train loss 2.6247, val loss 2.7743
# step 5830: train loss 2.6046, val loss 2.7430
# step 5840: train loss 2.6817, val loss 2.6642
# step 5850: train loss 2.6209, val loss 2.8203
# step 5860: train loss 2.5963, val loss 2.6335
# step 5870: train loss 2.6295, val loss 2.8099
# step 5880: train loss 2.6920, val loss 2.7531
# step 5890: train loss 2.5867, val loss 2.7564
# step 5900: train loss 2.5684, val loss 2.8581
# step 5910: train loss 2.5864, val loss 2.7250
# step 5920: train loss 2.6507, val loss 2.7389
# step 5930: train loss 2.6229, val loss 2.7527
# step 5940: train loss 2.5717, val loss 2.7895
# step 5950: train loss 2.6036, val loss 2.7764
# step 5960: train loss 2.5892, val loss 2.9578
# step 5970: train loss 2.6044, val loss 2.7632
# step 5980: train loss 2.5935, val loss 2.9194
# step 5990: train loss 2.6654, val loss 2.8776
# step 6000: train loss 2.6103, val loss 2.6877
# step 6010: train loss 2.5954, val loss 2.6437
# step 6020: train loss 2.6327, val loss 2.7098
# step 6030: train loss 2.6842, val loss 2.7246
# step 6040: train loss 2.6757, val loss 2.6592
# step 6050: train loss 2.6384, val loss 2.7243
# step 6060: train loss 2.6202, val loss 2.7358
# step 6070: train loss 2.6137, val loss 2.6799
# step 6080: train loss 2.6183, val loss 2.7894
# step 6090: train loss 2.5782, val loss 2.6586
# step 6100: train loss 2.5768, val loss 2.7726
# step 6110: train loss 2.6290, val loss 2.8037
# step 6120: train loss 2.5393, val loss 2.7079
# step 6130: train loss 2.5930, val loss 2.7348
# step 6140: train loss 2.5819, val loss 2.6975
# step 6150: train loss 2.6234, val loss 2.6676
# step 6160: train loss 2.5852, val loss 2.7644
# step 6170: train loss 2.6497, val loss 2.6824
# step 6180: train loss 2.6545, val loss 2.8197
# step 6190: train loss 2.5855, val loss 2.7357
# step 6200: train loss 2.6332, val loss 2.7356
# step 6210: train loss 2.6687, val loss 2.7794
# step 6220: train loss 2.6151, val loss 2.6693
# step 6230: train loss 2.5933, val loss 2.6321
# step 6240: train loss 2.5647, val loss 2.5601
# step 6250: train loss 2.6406, val loss 2.8704
# step 6260: train loss 2.6141, val loss 2.7273
# step 6270: train loss 2.7110, val loss 2.7515
# step 6280: train loss 2.5396, val loss 2.6917
# step 6290: train loss 2.6490, val loss 2.7437
# step 6300: train loss 2.5901, val loss 2.7140
# step 6310: train loss 2.6531, val loss 2.7220
# step 6320: train loss 2.5385, val loss 2.6774
# step 6330: train loss 2.6326, val loss 2.7077
# step 6340: train loss 2.5363, val loss 2.6470
# step 6350: train loss 2.6392, val loss 2.7778
# step 6360: train loss 2.5842, val loss 2.7091
# step 6370: train loss 2.5680, val loss 2.7660
# step 6380: train loss 2.6366, val loss 2.8405
# step 6390: train loss 2.6618, val loss 2.6934
# step 6400: train loss 2.5641, val loss 2.6325
# step 6410: train loss 2.5876, val loss 2.7986
# step 6420: train loss 2.5203, val loss 2.6916
# step 6430: train loss 2.5674, val loss 2.7666
# step 6440: train loss 2.5754, val loss 2.8119
# step 6450: train loss 2.5311, val loss 2.6080
# step 6460: train loss 2.5797, val loss 2.7420
# step 6470: train loss 2.5720, val loss 2.6506
# step 6480: train loss 2.6291, val loss 2.7026
# step 6490: train loss 2.5533, val loss 2.7627
# step 6500: train loss 2.6311, val loss 2.7429
# step 6510: train loss 2.5110, val loss 2.6920
# step 6520: train loss 2.6073, val loss 2.7321
# step 6530: train loss 2.5840, val loss 2.6631
# step 6540: train loss 2.6089, val loss 2.7521
# step 6550: train loss 2.5390, val loss 2.6620
# step 6560: train loss 2.4895, val loss 2.5819
# step 6570: train loss 2.5555, val loss 2.6331
# step 6580: train loss 2.5286, val loss 2.7721
# step 6590: train loss 2.5180, val loss 2.8269
# step 6600: train loss 2.6253, val loss 2.7423
# step 6610: train loss 2.5460, val loss 2.7569
# step 6620: train loss 2.5429, val loss 2.8220
# step 6630: train loss 2.5600, val loss 2.7854
# step 6640: train loss 2.6113, val loss 2.6955
# step 6650: train loss 2.6095, val loss 2.7462
# step 6660: train loss 2.5314, val loss 2.7597
# step 6670: train loss 2.6054, val loss 2.7248
# step 6680: train loss 2.5408, val loss 2.6498
# step 6690: train loss 2.5877, val loss 2.6856
# step 6700: train loss 2.5409, val loss 2.8038
# step 6710: train loss 2.5463, val loss 2.8247
# step 6720: train loss 2.6134, val loss 2.6022
# step 6730: train loss 2.6123, val loss 2.8788
# step 6740: train loss 2.4756, val loss 2.5243
# step 6750: train loss 2.4932, val loss 2.7907
# step 6760: train loss 2.6244, val loss 2.6295
# step 6770: train loss 2.5807, val loss 2.7473
# step 6780: train loss 2.6166, val loss 2.8818
# step 6790: train loss 2.6264, val loss 2.6176
# step 6800: train loss 2.4995, val loss 2.7430
# step 6810: train loss 2.6034, val loss 2.5633
# step 6820: train loss 2.6010, val loss 2.6853
# step 6830: train loss 2.6610, val loss 2.6497
# step 6840: train loss 2.5532, val loss 2.6318
# step 6850: train loss 2.6236, val loss 2.5713
# step 6860: train loss 2.5638, val loss 2.6485
# step 6870: train loss 2.5203, val loss 2.6884
# step 6880: train loss 2.5408, val loss 2.5972
# step 6890: train loss 2.5990, val loss 2.6635
# step 6900: train loss 2.6127, val loss 2.7005
# step 6910: train loss 2.5105, val loss 2.6559
# step 6920: train loss 2.6010, val loss 2.5901
# step 6930: train loss 2.4936, val loss 2.7632
# step 6940: train loss 2.5836, val loss 2.6058
# step 6950: train loss 2.6680, val loss 2.6723
# step 6960: train loss 2.5932, val loss 2.6161
# step 6970: train loss 2.6099, val loss 2.7480
# step 6980: train loss 2.5831, val loss 2.6770
# step 6990: train loss 2.5615, val loss 2.6617
# step 7000: train loss 2.6115, val loss 2.6047
# step 7010: train loss 2.4769, val loss 2.7443
# step 7020: train loss 2.5786, val loss 2.6407
# step 7030: train loss 2.5444, val loss 2.6892
# step 7040: train loss 2.5145, val loss 2.6810
# step 7050: train loss 2.5583, val loss 2.7477
# step 7060: train loss 2.5322, val loss 2.6164
# step 7070: train loss 2.5544, val loss 2.6645
# step 7080: train loss 2.5875, val loss 2.6055
# step 7090: train loss 2.6509, val loss 2.6852
# step 7100: train loss 2.5117, val loss 2.7844
# step 7110: train loss 2.6481, val loss 2.6712
# step 7120: train loss 2.5593, val loss 2.7661
# step 7130: train loss 2.5112, val loss 2.6314
# step 7140: train loss 2.5696, val loss 2.6564
# step 7150: train loss 2.5890, val loss 2.6983
# step 7160: train loss 2.5645, val loss 2.6258
# step 7170: train loss 2.5445, val loss 2.7824
# step 7180: train loss 2.5142, val loss 2.6607
# step 7190: train loss 2.5420, val loss 2.6671
# step 7200: train loss 2.6341, val loss 2.6758
# step 7210: train loss 2.4674, val loss 2.6332
# step 7220: train loss 2.4976, val loss 2.7436
# step 7230: train loss 2.5230, val loss 2.6530
# step 7240: train loss 2.6003, val loss 2.5500
# step 7250: train loss 2.6119, val loss 2.6544
# step 7260: train loss 2.5662, val loss 2.6507
# step 7270: train loss 2.5222, val loss 2.7032
# step 7280: train loss 2.5046, val loss 2.7044
# step 7290: train loss 2.6906, val loss 2.7230
# step 7300: train loss 2.5113, val loss 2.6907
# step 7310: train loss 2.5013, val loss 2.7020
# step 7320: train loss 2.5001, val loss 2.6138
# step 7330: train loss 2.5500, val loss 2.6560
# step 7340: train loss 2.5483, val loss 2.6788
# step 7350: train loss 2.5312, val loss 2.7775
# step 7360: train loss 2.4460, val loss 2.7033
# step 7370: train loss 2.5780, val loss 2.6334
# step 7380: train loss 2.5622, val loss 2.5996
# step 7390: train loss 2.5995, val loss 2.6055
# step 7400: train loss 2.5489, val loss 2.6786
# step 7410: train loss 2.5222, val loss 2.5477
# step 7420: train loss 2.5519, val loss 2.6886
# step 7430: train loss 2.5708, val loss 2.6396
# step 7440: train loss 2.5988, val loss 2.7812
# step 7450: train loss 2.4884, val loss 2.6842
# step 7460: train loss 2.5790, val loss 2.6030
# step 7470: train loss 2.4372, val loss 2.6018
# step 7480: train loss 2.4904, val loss 2.7995
# step 7490: train loss 2.5656, val loss 2.6223
# step 7500: train loss 2.5743, val loss 2.6353
# step 7510: train loss 2.5606, val loss 2.6267
# step 7520: train loss 2.5349, val loss 2.6680
# step 7530: train loss 2.5776, val loss 2.6211
# step 7540: train loss 2.5205, val loss 2.6008
# step 7550: train loss 2.5290, val loss 2.7171
# step 7560: train loss 2.5888, val loss 2.6883
# step 7570: train loss 2.5855, val loss 2.7352
# step 7580: train loss 2.5152, val loss 2.5678
# step 7590: train loss 2.5534, val loss 2.6620
# step 7600: train loss 2.5716, val loss 2.6447
# step 7610: train loss 2.5525, val loss 2.6104
# step 7620: train loss 2.4845, val loss 2.6893
# step 7630: train loss 2.6111, val loss 2.6605
# step 7640: train loss 2.5941, val loss 2.7119
# step 7650: train loss 2.6419, val loss 2.6050
# step 7660: train loss 2.4869, val loss 2.5628
# step 7670: train loss 2.5418, val loss 2.6491
# step 7680: train loss 2.4982, val loss 2.6412
# step 7690: train loss 2.6346, val loss 2.6381
# step 7700: train loss 2.5333, val loss 2.5595
# step 7710: train loss 2.5702, val loss 2.5543
# step 7720: train loss 2.5134, val loss 2.7642
# step 7730: train loss 2.5739, val loss 2.6560
# step 7740: train loss 2.5683, val loss 2.5285
# step 7750: train loss 2.6187, val loss 2.7637
# step 7760: train loss 2.5328, val loss 2.6884
# step 7770: train loss 2.5332, val loss 2.5667
# step 7780: train loss 2.4879, val loss 2.8064
# step 7790: train loss 2.5566, val loss 2.6726
# step 7800: train loss 2.4888, val loss 2.6552
# step 7810: train loss 2.5370, val loss 2.7145
# step 7820: train loss 2.5631, val loss 2.6440
# step 7830: train loss 2.5263, val loss 2.6064
# step 7840: train loss 2.5511, val loss 2.7522
# step 7850: train loss 2.5552, val loss 2.6424
# step 7860: train loss 2.5707, val loss 2.8186
# step 7870: train loss 2.4489, val loss 2.6392
# step 7880: train loss 2.5507, val loss 2.4817
# step 7890: train loss 2.5040, val loss 2.5304
# step 7900: train loss 2.5601, val loss 2.6838
# step 7910: train loss 2.5052, val loss 2.7515
# step 7920: train loss 2.5751, val loss 2.7331
# step 7930: train loss 2.5450, val loss 2.6509
# step 7940: train loss 2.5256, val loss 2.6262
# step 7950: train loss 2.5232, val loss 2.6831
# step 7960: train loss 2.5787, val loss 2.6004
# step 7970: train loss 2.5793, val loss 2.6763
# step 7980: train loss 2.4948, val loss 2.5491
# step 7990: train loss 2.4487, val loss 2.5399
# step 8000: train loss 2.5643, val loss 2.7007
# step 8010: train loss 2.5216, val loss 2.5524
# step 8020: train loss 2.4895, val loss 2.7340
# step 8030: train loss 2.4736, val loss 2.7537
# step 8040: train loss 2.5702, val loss 2.5944
# step 8050: train loss 2.5594, val loss 2.5915
# step 8060: train loss 2.4708, val loss 2.7653
# step 8070: train loss 2.5063, val loss 2.6232
# step 8080: train loss 2.5282, val loss 2.5215
# step 8090: train loss 2.4584, val loss 2.6417
# step 8100: train loss 2.4826, val loss 2.5786
# step 8110: train loss 2.4603, val loss 2.6629
# step 8120: train loss 2.5297, val loss 2.5445
# step 8130: train loss 2.4818, val loss 2.7116
# step 8140: train loss 2.5149, val loss 2.6729
# step 8150: train loss 2.4863, val loss 2.5947
# step 8160: train loss 2.5316, val loss 2.6234
# step 8170: train loss 2.4297, val loss 2.6826
# step 8180: train loss 2.5193, val loss 2.5638
# step 8190: train loss 2.5102, val loss 2.6813
# step 8200: train loss 2.5294, val loss 2.5391
# step 8210: train loss 2.5151, val loss 2.7513
# step 8220: train loss 2.4982, val loss 2.6783
# step 8230: train loss 2.5550, val loss 2.6319
# step 8240: train loss 2.5028, val loss 2.6914
# step 8250: train loss 2.4946, val loss 2.6267
# step 8260: train loss 2.5221, val loss 2.7874
# step 8270: train loss 2.5351, val loss 2.7538
# step 8280: train loss 2.5476, val loss 2.6028
# step 8290: train loss 2.5593, val loss 2.6890
# step 8300: train loss 2.4858, val loss 2.4781
# step 8310: train loss 2.5019, val loss 2.5998
# step 8320: train loss 2.5088, val loss 2.6960
# step 8330: train loss 2.4646, val loss 2.6189
# step 8340: train loss 2.4692, val loss 2.6525
# step 8350: train loss 2.4830, val loss 2.6994
# step 8360: train loss 2.4689, val loss 2.5730
# step 8370: train loss 2.5231, val loss 2.5843
# step 8380: train loss 2.5298, val loss 2.6556
# step 8390: train loss 2.4777, val loss 2.5484
# step 8400: train loss 2.4766, val loss 2.6225
# step 8410: train loss 2.5442, val loss 2.5211
# step 8420: train loss 2.3827, val loss 2.5853
# step 8430: train loss 2.5401, val loss 2.6507
# step 8440: train loss 2.5034, val loss 2.6393
# step 8450: train loss 2.4836, val loss 2.5678
# step 8460: train loss 2.5389, val loss 2.5503
# step 8470: train loss 2.5706, val loss 2.5718
# step 8480: train loss 2.5020, val loss 2.6022
# step 8490: train loss 2.5130, val loss 2.6277
# step 8500: train loss 2.5513, val loss 2.5028
# step 8510: train loss 2.5322, val loss 2.6066
# step 8520: train loss 2.4670, val loss 2.4888
# step 8530: train loss 2.5737, val loss 2.5791
# step 8540: train loss 2.4815, val loss 2.5926
# step 8550: train loss 2.5515, val loss 2.5465
# step 8560: train loss 2.4279, val loss 2.6543
# step 8570: train loss 2.4602, val loss 2.5778
# step 8580: train loss 2.5896, val loss 2.6165
# step 8590: train loss 2.5324, val loss 2.6168
# step 8600: train loss 2.5355, val loss 2.7252
# step 8610: train loss 2.4223, val loss 2.5904
# step 8620: train loss 2.5428, val loss 2.5044
# step 8630: train loss 2.4104, val loss 2.7008
# step 8640: train loss 2.3869, val loss 2.5614
# step 8650: train loss 2.5520, val loss 2.5936
# step 8660: train loss 2.4407, val loss 2.5710
# step 8670: train loss 2.3791, val loss 2.5703
# step 8680: train loss 2.4571, val loss 2.5691
# step 8690: train loss 2.4611, val loss 2.6160
# step 8700: train loss 2.4385, val loss 2.5644
# step 8710: train loss 2.5458, val loss 2.5496
# step 8720: train loss 2.5523, val loss 2.5718
# step 8730: train loss 2.5463, val loss 2.6340
# step 8740: train loss 2.4789, val loss 2.6767
# step 8750: train loss 2.5319, val loss 2.6374
# step 8760: train loss 2.5104, val loss 2.6258
# step 8770: train loss 2.5295, val loss 2.5828
# step 8780: train loss 2.5095, val loss 2.7449
# step 8790: train loss 2.5256, val loss 2.6168
# step 8800: train loss 2.4914, val loss 2.6560
# step 8810: train loss 2.5072, val loss 2.6235
# step 8820: train loss 2.5019, val loss 2.5737
# step 8830: train loss 2.5621, val loss 2.7060
# step 8840: train loss 2.4685, val loss 2.5830
# step 8850: train loss 2.5783, val loss 2.6537
# step 8860: train loss 2.4610, val loss 2.5342
# step 8870: train loss 2.5258, val loss 2.5764
# step 8880: train loss 2.4204, val loss 2.6210
# step 8890: train loss 2.4531, val loss 2.6116
# step 8900: train loss 2.4171, val loss 2.5620
# step 8910: train loss 2.4846, val loss 2.6000
# step 8920: train loss 2.5212, val loss 2.5509
# step 8930: train loss 2.4868, val loss 2.5662
# step 8940: train loss 2.5383, val loss 2.4884
# step 8950: train loss 2.4706, val loss 2.5937
# step 8960: train loss 2.4479, val loss 2.6861
# step 8970: train loss 2.4909, val loss 2.5816
# step 8980: train loss 2.4713, val loss 2.5256
# step 8990: train loss 2.5248, val loss 2.6562
# step 9000: train loss 2.4702, val loss 2.6404
# step 9010: train loss 2.5200, val loss 2.7089
# step 9020: train loss 2.5441, val loss 2.5531
# step 9030: train loss 2.4702, val loss 2.6727
# step 9040: train loss 2.5637, val loss 2.6212
# step 9050: train loss 2.5173, val loss 2.6740
# step 9060: train loss 2.4700, val loss 2.5685
# step 9070: train loss 2.4737, val loss 2.5113
# step 9080: train loss 2.4743, val loss 2.4575
# step 9090: train loss 2.4813, val loss 2.5890
# step 9100: train loss 2.5436, val loss 2.5353
# step 9110: train loss 2.5261, val loss 2.5788
# step 9120: train loss 2.4540, val loss 2.5324
# step 9130: train loss 2.5389, val loss 2.6441
# step 9140: train loss 2.5607, val loss 2.5038
# step 9150: train loss 2.4927, val loss 2.6528
# step 9160: train loss 2.4555, val loss 2.6402
# step 9170: train loss 2.4190, val loss 2.6114
# step 9180: train loss 2.5434, val loss 2.6562
# step 9190: train loss 2.5499, val loss 2.6253
# step 9200: train loss 2.4971, val loss 2.5206
# step 9210: train loss 2.5524, val loss 2.5667
# step 9220: train loss 2.5056, val loss 2.5769
# step 9230: train loss 2.4833, val loss 2.5336
# step 9240: train loss 2.4786, val loss 2.5827
# step 9250: train loss 2.5121, val loss 2.6757
# step 9260: train loss 2.5513, val loss 2.6422
# step 9270: train loss 2.4498, val loss 2.6070
# step 9280: train loss 2.5639, val loss 2.5859
# step 9290: train loss 2.4504, val loss 2.6903
# step 9300: train loss 2.5102, val loss 2.5269
# step 9310: train loss 2.4082, val loss 2.5585
# step 9320: train loss 2.4856, val loss 2.6218
# step 9330: train loss 2.4763, val loss 2.5093
# step 9340: train loss 2.4237, val loss 2.4548
# step 9350: train loss 2.5103, val loss 2.5208
# step 9360: train loss 2.4909, val loss 2.6348
# step 9370: train loss 2.4378, val loss 2.5085
# step 9380: train loss 2.4883, val loss 2.5913
# step 9390: train loss 2.4994, val loss 2.5311
# step 9400: train loss 2.5050, val loss 2.5766
# step 9410: train loss 2.4758, val loss 2.4711
# step 9420: train loss 2.4228, val loss 2.6440
# step 9430: train loss 2.4959, val loss 2.6705
# step 9440: train loss 2.4941, val loss 2.5918
# step 9450: train loss 2.4166, val loss 2.6521
# step 9460: train loss 2.5071, val loss 2.6375
# step 9470: train loss 2.4834, val loss 2.5219
# step 9480: train loss 2.5086, val loss 2.5329
# step 9490: train loss 2.4477, val loss 2.5746
# step 9500: train loss 2.4837, val loss 2.5786
# step 9510: train loss 2.4892, val loss 2.5847
# step 9520: train loss 2.4525, val loss 2.5741
# step 9530: train loss 2.4673, val loss 2.5998
# step 9540: train loss 2.4926, val loss 2.6002
# step 9550: train loss 2.5545, val loss 2.5338
# step 9560: train loss 2.4979, val loss 2.5412
# step 9570: train loss 2.5082, val loss 2.5741
# step 9580: train loss 2.4614, val loss 2.5800
# step 9590: train loss 2.3851, val loss 2.4897
# step 9600: train loss 2.5330, val loss 2.5184
# step 9610: train loss 2.3507, val loss 2.6219
# step 9620: train loss 2.4565, val loss 2.4867
# step 9630: train loss 2.4799, val loss 2.5325
# step 9640: train loss 2.4072, val loss 2.5671
# step 9650: train loss 2.4797, val loss 2.6548
# step 9660: train loss 2.4470, val loss 2.5351
# step 9670: train loss 2.5199, val loss 2.6081
# step 9680: train loss 2.5397, val loss 2.5341
# step 9690: train loss 2.4709, val loss 2.5575
# step 9700: train loss 2.4357, val loss 2.5985
# step 9710: train loss 2.4645, val loss 2.4887
# step 9720: train loss 2.5234, val loss 2.4891
# step 9730: train loss 2.5131, val loss 2.6106
# step 9740: train loss 2.4338, val loss 2.5185
# step 9750: train loss 2.5518, val loss 2.5370
# step 9760: train loss 2.4647, val loss 2.6048
# step 9770: train loss 2.4997, val loss 2.6428
# step 9780: train loss 2.5503, val loss 2.5644
# step 9790: train loss 2.3791, val loss 2.6371
# step 9800: train loss 2.4325, val loss 2.5311
# step 9810: train loss 2.4704, val loss 2.5639
# step 9820: train loss 2.4890, val loss 2.7150
# step 9830: train loss 2.4853, val loss 2.6450
# step 9840: train loss 2.4984, val loss 2.5581
# step 9850: train loss 2.4975, val loss 2.4810
# step 9860: train loss 2.4532, val loss 2.4760
# step 9870: train loss 2.4826, val loss 2.5414
# step 9880: train loss 2.5028, val loss 2.4159
# step 9890: train loss 2.5004, val loss 2.5028
# step 9900: train loss 2.4371, val loss 2.4773
# step 9910: train loss 2.5281, val loss 2.5616
# step 9920: train loss 2.4426, val loss 2.5503
# step 9930: train loss 2.4742, val loss 2.5201
# step 9940: train loss 2.4323, val loss 2.4705
# step 9950: train loss 2.4815, val loss 2.5229
# step 9960: train loss 2.4188, val loss 2.5662
# step 9970: train loss 2.5432, val loss 2.5154
# step 9980: train loss 2.3994, val loss 2.4916
# step 9990: train loss 2.5291, val loss 2.4690

# %%
idx = torch.ones((1,1), dtype=torch.long)*3
print (decode(m.generate(idx, max_new_tokens=100)[0].tolist()))
# Out:
# 'u9Â1ÉhîÉlâX1LÔbM?SôMeb]ÈYgSi3.6PwOp6Ë:'ç1aÉX Ék'KiéWÈS,ëE)Câ;P'Bs·P[(,ôB,âVÆwUP';ÉrSheZ,EÀ0(ZÉPdy_6k

# %% [markdown]
# ## Single Head Attention
#
# Nous allons maintenant implémenter le mécanisme de base de l'attention. Pour chaque couple de mots de la séquence, ce mécanisme combine Q une *query* (l'information recherchée), K une *key* (l'information obtenue) et calcule  V une *value*, un vecteur de résultat.
#
# ![single head attention](images/single_head_attention.png)
#
# ### Masquage
# Cependant, comme nous utilisons le modèle pour générer des séquences, on ne doit pas utiliser les caractères situés après le caractère courant, car ce sont justement ces caractères que l'on cherche à prédire lors de l'apprentissage : *le futur n'est pas utilisé pour prédire (le futur).*
#
# On va donc intégrer une matrice de masquage dans le processus. Cette matrice indique que pour le premier caractère de la séquence, on ne peux utiliser que ce caractère pour prédire (pas de contexte). Pour le second caractère, on peut utiliser le premier caractère et le second. Pour le troisième caractère, on peut utiliser le premier, le second et le troisième et ainsi de suite. Cette matrice est donc une matrice triangulaire inférieure. Cette matrice est normalisée par ligne (les lignes somment à 1).

# %%
T = 8

# first version of the contraints with matrix multiplication
# create a lower triangular matrix
weights0 = torch.tril(torch.ones(T,T))
# normalize each row
weights0 = weights0 / weights0.sum(1, keepdim=True) 
print (weights0)
# Out:
# tensor([[1.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000],
#         [0.5000, 0.5000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000],
#         [0.3333, 0.3333, 0.3333, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000],
#         [0.2500, 0.2500, 0.2500, 0.2500, 0.0000, 0.0000, 0.0000, 0.0000],
#         [0.2000, 0.2000, 0.2000, 0.2000, 0.2000, 0.0000, 0.0000, 0.0000],
#         [0.1667, 0.1667, 0.1667, 0.1667, 0.1667, 0.1667, 0.0000, 0.0000],
#         [0.1429, 0.1429, 0.1429, 0.1429, 0.1429, 0.1429, 0.1429, 0.0000],
#         [0.1250, 0.1250, 0.1250, 0.1250, 0.1250, 0.1250, 0.1250, 0.1250]])

# %% [markdown]
# La couche [`softmax`](https://pytorch.org/docs/stable/generated/torch.nn.functional.softmax.html) est une autre manière de réaliser la normalisation :
#
# Question :
# > * Vérifier qu'on obtient bien la même matrice.

# %%
tril = torch.tril(torch.ones(T,T))
weights = torch.tril(torch.ones(T,T))
weights = weights.masked_fill(tril== 0, float('-inf'))
weights = nn.functional.softmax(weights, dim=-1)
print (weights)
# Out:
# tensor([[1.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000],
#         [0.5000, 0.5000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000],
#         [0.3333, 0.3333, 0.3333, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000],
#         [0.2500, 0.2500, 0.2500, 0.2500, 0.0000, 0.0000, 0.0000, 0.0000],
#         [0.2000, 0.2000, 0.2000, 0.2000, 0.2000, 0.0000, 0.0000, 0.0000],
#         [0.1667, 0.1667, 0.1667, 0.1667, 0.1667, 0.1667, 0.0000, 0.0000],
#         [0.1429, 0.1429, 0.1429, 0.1429, 0.1429, 0.1429, 0.1429, 0.0000],
#         [0.1250, 0.1250, 0.1250, 0.1250, 0.1250, 0.1250, 0.1250, 0.1250]])

# %% [markdown]
# ### Implémentation
#
# Nous pouvons maintenant implémenter la couche d'attention :
#
# ![attention_formula](images/attention_formula.png)

# %% [markdown]
# Questions :
#
# > * Créer les couches key, query et value comme des couches linéaires de dimension `C` x `head_size`.
# > * Appliquer les couches à `x`.
# > * `weights = query x key` (transposer les deuxième et troisième dimensions de key pour pouvoir faire le produit).
# > * Appliquer le facteur de normalisation.
# > * Appliquer le masque triangulaire et la softmax à `weights`.
# > * Appliquer value à `x`.
# > * Le résultat `out` est la multiplication de `weights` par `value(x)`.

# %%
head_size = 16
B, T, C = 4, 8, 32
x = torch.randn(B, T, C)
## YOUR CODE HERE
import torch.nn.functional as F
# define the Key layer  
key = torch.nn.Linear(C, head_size) 
# define the Query layer
query = torch.nn.Linear(C, head_size)
# define the Value layer
value =  torch.nn.Linear(C, head_size)
# apply each layer to the input
k =key(x)  # (B, T, head_size)
q = query(x) # (B, T, head_size)
v = value(x) # (B, T, head_size)
# compute the normalize product between Q and K 
weights = torch.bmm(q, k.transpose(1, 2)) # (B, T, head_size) @ (B, 16, head_size) -> (B, T, T)
# apply the mask (lower triangular matrix)
weights = weights.masked_fill(tril== 0, float('-inf'))
# apply the softmax
weights = F.softmax(weights, dim=-1)
###
out  = weights @ value(x) # (B, T, head_size)

# print the result
print("Weights[0]:\n", weights[0])  
print("Output[0]:\n", out[0])
# Out:
# Weights[0]:
#  tensor([[1.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000],
#         [0.7708, 0.2292, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000],
#         [0.6764, 0.1056, 0.2180, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000],
#         [0.0493, 0.1134, 0.0035, 0.8338, 0.0000, 0.0000, 0.0000, 0.0000],
#         [0.0843, 0.0794, 0.4275, 0.2816, 0.1272, 0.0000, 0.0000, 0.0000],
#         [0.5064, 0.1615, 0.2878, 0.0021, 0.0289, 0.0133, 0.0000, 0.0000],
#         [0.2550, 0.0683, 0.3723, 0.0511, 0.0904, 0.1244, 0.0384, 0.0000],
#         [0.2489, 0.0836, 0.0315, 0.0294, 0.1417, 0.3339, 0.0553, 0.0757]],
#        grad_fn=<SelectBackward0>)
# Output[0]:
#  tensor([[-0.2341, -1.0270, -0.2843, -0.3103,  0.5312,  0.1632,  0.5229,  0.5325,
#           0.2807,  0.0490,  1.1303,  0.1615, -0.7270,  0.4876,  0.3824, -0.2562],
#         [-0.1534, -0.6405, -0.1427, -0.5283,  0.2434,  0.0489,  0.5092,  0.3375,
#           0.2537,  0.1122,  0.7364,  0.1209, -0.3379,  0.4202,  0.2837, -0.1775],
#         [-0.0461, -0.3962,  0.0626, -0.3598,  0.2413,  0.1359,  0.4709,  0.5194,
#           0.1729,  0.0776,  0.6404,  0.0487, -0.3796,  0.2614,  0.3984, -0.1552],
#         [ 0.5302,  0.6048,  0.7599, -0.8313,  0.1425,  0.0406, -0.0265,  0.0846,
#          -0.3685,  0.4636, -0.1212, -0.1933,  0.7352, -0.4944, -0.3604,  0.6005],
#         [ 0.2944,  0.6607,  0.5918, -0.3987, -0.0629,  0.0431,  0.1582,  0.3347,
#          -0.1522,  0.0635, -0.0699, -0.1590,  0.3217, -0.3370,  0.2815,  0.1850],
#         [ 0.0126, -0.0963,  0.1755, -0.3788,  0.0910,  0.0869,  0.4276,  0.4470,
#           0.1215,  0.0557,  0.4037,  0.0055, -0.1602,  0.1541,  0.4061, -0.1035],
#         [ 0.0911,  0.2498,  0.2405, -0.1009,  0.0592,  0.0591,  0.2578,  0.3299,
#          -0.0123, -0.1185,  0.1581, -0.0434,  0.1591, -0.0482,  0.4798, -0.0299],
#         [-0.1832, -0.0382, -0.2698,  0.0780,  0.1155, -0.1257,  0.1151, -0.0783,
#           0.0569, -0.3500,  0.2765,  0.0773,  0.4951,  0.1755,  0.4553, -0.0876]],
#        grad_fn=<SelectBackward0>)

# %% [markdown]
# Questions :
#
# > * Copier votre code dans `gpt_single_head.py` : la définition des couches dans le constructeur de la classe `Head` et les calculs dans la fonction `forward`.
# > * Faire un entrainement.
# > * Quelle loss en train et val obtenez vous ? Le texte vous parait-il meilleur ?

# %% [raw]
# Non le texte ne me parait pas meilleur

# %%
from importlib import reload
import gpt_single_head as G
reload(G)
# Out:
# 0.009989 M parameters
# step 0: train loss 4.6896, val loss 4.6661
# step 500: train loss 0.5564, val loss 0.5934
# step 1000: train loss 0.4698, val loss 0.4759
# step 1500: train loss 0.4441, val loss 0.4480
# step 2000: train loss 0.4219, val loss 0.4275
# step 2500: train loss 0.4204, val loss 0.4200
# step 3000: train loss 0.4118, val loss 0.4103
# step 3500: train loss 0.4056, val loss 0.4098
# step 4000: train loss 0.3988, val loss 0.3949
# step 4500: train loss 0.4033, val loss 0.3929
# step 4999: train loss 0.3988, val loss 0.3885
#
# LLLLLLLLLLLLLL'...
# <module 'gpt_single_head' from '/home/onyxia/work/nlp-lab_language-models/gpt_single_head.py'>

# %% [markdown]
# ## Multi-head attention
#
# La *multi-head attention* est simplement le calcul en parallèle de plusieurs *single head attention*. Chacune des single head attention est concaténée pour créer la sortie de la multi-head attention. Dans la figure issue de l'article original, le nombre de *heads* dans le *multi-head* est `h`. Afin d'opérer des combinaisons pondérées sur la sortie de chacune des single head, une couche de calcul linéaire est ajoutée.
#
# ![multi head attention](images/multi_head_attention.png)
#
# Le code ci-dessous crée un module de multi-head attention.
# Questions :
# > * Dans le constructeur, créer une liste contenant `num_heads` module `Head` en utilisant la fonction [ModuleList](https://pytorch.org/docs/stable/generated/torch.nn.ModuleList.html) de pytorch.
# > * Dans la fonction `forward`, appliquer chaque single head à l'input et concaténer le résultat en utilisant la fonction [cat](https://pytorch.org/docs/stable/generated/torch.cat.html) de pytorch.

# %%
class Head(nn.Module):
    def __init__(self, head_size):
        super().__init__()
        self.head_size = head_size
        self.key = nn.Linear(head_size, head_size)
        self.query = nn.Linear(head_size, head_size)
        self.value = nn.Linear(head_size, head_size)
        
    def forward(self, x):
        # Applique les transformations de Key, Query et Value
        k = self.key(x)  # (B, T, head_size)
        q = self.query(x)  # (B, T, head_size)
        v = self.value(x)  # (B, T, head_size)
        
        # Calcul du produit de Q et K pour obtenir les poids d'attention
        weights = torch.bmm(q, k.transpose(1, 2))  # (B, T, head_size) @ (B, head_size, T) -> (B, T, T)
        
        # Appliquer softmax sur les poids pour obtenir la distribution d'attention
        weights = torch.nn.functional.softmax(weights, dim=-1)  # (B, T, T)
        
        # Appliquer les poids d'attention sur les valeurs
        out = torch.bmm(weights, v)  # (B, T, T) @ (B, T, head_size) -> (B, T, head_size)
        
        return out







class MultiHeadAttention(nn.Module):
    """ multiple heads of self-attention in parallel """

    def __init__(self, num_heads, head_size):
        super().__init__()
        ## YOUR CODE HERE
        ## list of num_heads modules of type Head
        self.heads = nn.ModuleList([Head(head_size) for _ in range(num_heads)])
        ###
        
        
    def forward(self, x):
        ## YOUR CODE HERE
        ## apply each head in self.heads to x and concat the results 
        out = torch.cat([h(x) for h in self.heads], dim=-1)

        return out

# %% [markdown]
# Questions :
# > * Copier le fichier `gpt_single_head.py` en `gpt_multi_head.py`.
# > * Ajouter le module MultiHeadAttention dans `gpt_multi_head.py`.
# > * En tête de fichier, ajouter un paramètre  `n_head = 4`.
# > * Dans le module BigramLanguageModel, remplacer le module Head par un module MultiHeadAttention avec les paramètres `num_heads = n_head` et `head_size = n_embd // n_head` pour garder le même nombre de paramètres.
# > Relancer l'entrainement et noter le nombre de paramètres et les loss obtenues.
#
# 0.009893 M parameters
# step 4999: train loss 2.1570, val loss 2.1802

# %% [markdown]
# ## Ajout d'une couche de calcul FeedForward
#
#
# Après les couches d'attention qui collectent l'information dans la séquence, une couche de calcul est ajoutée pour combiner toutes les informations de la séquence. Cette couche est un simple Multi-Layer-Perceptron avec une couche cachée et une non linéarité de type [RELU](https://pytorch.org/docs/stable/generated/torch.nn.ReLU.html).
# ![multi feedfoward](images/multi_ff.png)

# %%
class FeedForward(nn.Module):
    """ a simple MLP with RELU """

    def __init__(self, n_embd):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(n_embd, n_embd),
            nn.ReLU(),
        )

    def forward(self, x):
        return self.net(x)

# %% [markdown]
# Questions :
# > * Ajouter le module `FeedForward` dans votre fichier `gpt_multi_head.py`.
# > * Ajouter cette couche `FeedForward` après la *multi-head attention*.
# > * Relancer l'entrainement et noter le nombre de paramètres et les loss obtenues.

# %% [markdown]
# 0.010949 M parameters
# step 4999: train loss 2.1290, val loss 2.1216

# %%
from importlib import reload
import gpt_multi_head as G
reload(G)
# Out:
# 0.022661 M parameters
# step 0: train loss 4.6491, val loss 4.6626
# step 500: train loss 3.1173, val loss 3.1449
# step 1000: train loss 3.0738, val loss 3.0825
# step 1500: train loss 2.5790, val loss 2.5967
# step 2000: train loss 2.4037, val loss 2.4332
# step 2500: train loss 2.3256, val loss 2.3694
# step 3000: train loss 2.2803, val loss 2.3080
# step 3500: train loss 2.2545, val loss 2.2505
# step 4000: train loss 2.2303, val loss 2.2269
# step 4500: train loss 2.2108, val loss 2.1992
# step 4999: train loss 2.2079, val loss 2.1526
#
# Vis bait laus das que aiseumaique son l'éunsenvite on plége dotmeun ar bonr limievis;
# Le sobbhex
# Le la l'aversque mi ferfais, tomme L'énège:
# Sa mon, ves, la veullas qu'un nautis est toites eut ufnsaalle esdre.
# L'hon -De Des que,
# Cies bannes amme et pune-rit jyarte en vaveus, celplofunée daz moitte, cafmon.
#
#              ·
# Oleu:
# Le la es de voite, Lorrile que ple endovê4mes.
#
# NRIÀ--Jau miose Raniéte; pril sonmroit!
# Utemie!n hannecssoir, taur, à loioriez qu'In oshaivite,
# Ô ù joil lers Acue, pènce
# 0.022661 M parameters
# step 0: train loss 4.6491, val loss 4.6626
# step 500: train loss 3.1173, val loss 3.1449
# step 1000: train loss 3.0738, val loss 3.0825
# step 1500: train loss 2.5790, val loss 2.5967
# step 2000: train loss 2.4037, val loss 2.4332
# step 2500: train loss 2.3256, val loss 2.3694
# step 3000: train loss 2.2803, val loss 2.3080
# step 3500: train loss 2.2545, val loss 2.2505
# step 4000: train loss 2.2303, val loss 2.2269
# step 4500: train loss 2.2108, val loss 2.1992
# step 4999: train loss 2.2079, val loss 2.1526
#
# Vis bait laus das que aiseumaique son l'éunsenvite on plége dotmeun ar bonr limievis;
# Le sobbhex
# Le la l'aversque mi ferfais, tomme L'énège:
# Sa mon, ves, la veullas qu'un nautis est toites eut ufnsaalle esdre.
# L'hon -De Des que,
# Cies bannes amme et pune-rit jyarte en vaveus, celplofunée daz moitte, cafmon.
#
#              ·
# Oleu:
# Le la es de voite, Lorrile que ple endovê4mes.
#
# NRIÀ--Jau miose Raniéte; pril sonmroit!
# Utemie!n hannecssoir, taur, à loioriez qu'In oshaivite,
# Ô ù joil lers Acue, pènce
# <module 'gpt_multi_head' from '/home/onyxia/work/nlp-lab_language-models/gpt_multi_head.py'>

# %% [markdown]
# ## Empiler les blocs
#
# Le réseau construit jusqu'à présent n'est en fait qu'un bloc du réseau final. Il est maintenant possible d'empiler les blocs de *multi-head attention* pour créer un réseau profond.
#
# ![multi feedfoward](images/multi_bloc.png)
#
#
# Le code suivant crée un bloc :

# %%
class Block(nn.Module):
    """ A single bloc of multi-head attention """

    def __init__(self, n_embd, n_head):
        super().__init__()
        head_size = n_embd // n_head
        self.sa = MultiHeadAttention(n_head, head_size)
        self.ffwd = FeedForward(n_embd)

    def forward(self, x):
        x = self.sa(x)
        x = self.ffwd(x)
        return x

# %% [markdown]
# Questions :
# > * Ajouter le module `Block` dans `gpt_multi_head.py`.
# > * Modifier le code de `BigramLanguageModel` pour ajouter 3 `Block(n_embd, n_head=4)` avec un container [Sequential](https://pytorch.org/docs/stable/generated/torch.nn.Sequential.html) à la place de `MultiHeadAttention`et `FeedForward`.
# > * Relancer l'entrainement et noter le nombre de paramètres et les loss obtenues.
#
# 0.019205 M parameters
# step 4999: train loss 2.2080, val loss 2.2213

# %% [markdown]
# ## Amélioration de l'entraînement
#
# Si on veut continuer à augmenter la taille du réseau, il est nécessaire d'utiliser des couches permettant d'améliorer l'entraînement et ses capacités de généralisation (réduire le sur-apprentissage). Ces couches sont :
# - *skip connections* ou *residual connections*
# - les couches de normalisation
# - le dropout.
#
#
# ![multi feedfoward](images/multi_skip_norm.png)
#
#
# Questions :
# > * Dans le module Block, ajouter une skip connection en ajoutant l'input dans chaque connexion :
# ```
#         x = x + self.sa(self.ln1(x))
#         x = x + self.ffwd(self.ln2(x))
# ```
# > * Dans le module Block, ajouter 2 couches de [LayerNorm](https://pytorch.org/docs/stable/generated/torch.nn.LayerNorm.html) de taille `n_embd` avant la couche de `Multi-Head attention` et avant la `FeedForward`.
# > * Après la série de 3 blocs, ajouter une couche de LayerNorm de taille `n_embd`.
# > * Définir une variable `dropout = 0.2` en début de fichier et ajouter une couche de [Dropout](https://pytorch.org/docs/stable/generated/torch.nn.Dropout.html) :
# >    * Après la couche RELU dans FeedForward
# >    * Après la couche de MultiHead dans `MultiHeadAttention`
# >    * Après la softmax dans la single head attention `Head`.
# > * Relancer l'entrainement et noter le nombre de paramètres et les loss obtenues.
#
# 0.019653 M parameters

# %%
from importlib import reload
import gpt_multi_head as G
reload(G)
# Out:
# 0.023109 M parameters
# step 0: train loss 4.7772, val loss 4.7726
# step 500: train loss 2.4534, val loss 2.5041
# step 1000: train loss 2.2850, val loss 2.2988
# step 1500: train loss 2.2197, val loss 2.2232
# step 2000: train loss 2.1688, val loss 2.1730
# step 2500: train loss 2.1217, val loss 2.1303
# step 3000: train loss 2.1042, val loss 2.0819
# step 3500: train loss 2.0848, val loss 2.0678
# step 4000: train loss 2.0573, val loss 2.0328
# step 4500: train loss 2.0536, val loss 2.0334
# step 4999: train loss 2.0543, val loss 2.0216
#
#
#                 Pe le les mour. la n'us maité,
# Pent Muuâter,
# Loite ou douts le bris étempress  yeft le cesis preôTez-réte.
#
# Pantroplôt de de danoe aine janfapsuille sais s'hommére que nor-vees,
# IVIN
# Me das, un l'umes: ceu splos vaans que fugessonnuser pent la taispré, haièvan!
# Jolytre au le meré sle «J'ustres
# Où plommez
# Punt dans à vaâmo.
#
#
# E plezur la même la ce échasdoù en ble sêve, lant pa parsta chous dre la vez tous de me choix!
# Que voiol à bar et ux de cis lait, pière.
# Les faple au
# <module 'gpt_multi_head' from '/home/onyxia/work/nlp-lab_language-models/gpt_multi_head.py'>

# %% [markdown]
# ## Conclusion
#
# Les principaux éléments de GPT2 sont en place, il faut maintenant faire passer le modèle à l'échelle et l'entraîner sur une base de données beaucoup plus grande. Pour comparaison, les paramètres de [GPT2](https://huggingface.co/transformers/v2.11.0/model_doc/gpt2.html) sont :
#
# * `vocab_size = 50257` : GPT2 modélise des tokens (subwords) alors que nous modélisons des caractères. Pour nous, `vocab_size = 100`.
# * `n_positions = 1024` : la taille maximale du contexte. Pour nous, c'est `block_size = 8`.
# * `n_embd = 768`:  la dimension des embeddings. Pour nous c'est `n_embd = 32`.
# * `n_layer = 12`: le nombre de block. Pour nous c'est 3.
# * `n_head = 12`: le nombre de multi-head attention. Pour nous c'est 4.
#
# Au total, GPT2 est composé de 1,500 millions de paramètres et a été entrainé sur 8M de pages web, soit 40 Gb de texte.
#
#
# ```
# 10.816613 M parameters
# step 0: train loss 4.7847, val loss 4.7701
# step 4999: train loss 0.2683, val loss 2.1161
# time: 31m47.910s
#
# Le pêcheur où l'homme en peu de Carevante
# Sa conter des chosses qu'en ses yoitn!
#
# Ils sont là-hauts parler à leurs ténèbres
# A ceux qu'on rêve aux oiseaux des cheveux,
# Et celus qu'on tourna jamais sous le front;
# Ils se disent tu mêle aux univers.
# J'ai vu Jean vu France, potte; petits contempler,
# Et petié calme au milibre et versait,
# M'éblouissant, emportant, écoute, ingorancessible,
# On meurt s'efferayait.....--Pas cont âme parle en Apparia!
# ```
